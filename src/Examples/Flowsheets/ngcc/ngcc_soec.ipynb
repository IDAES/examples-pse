# %% [markdown]
# # Design Flowsheet for NGCC + SOEC with Steam Integration
#
# This flowsheet example provides an off-design model for integration of an SOEC for hydrogen production with an NGCC.  The NGCC nominally produces 650 MW net, and includeds 97% CO2 capture.  A detailed SOEC unit model is used here.

# %% [markdown]
# ## Import Required Modules

# %%
import os
import math
import numpy as np
import pytest
from IPython.core.display import SVG
import pyomo.environ as pyo
from idaes.core.solvers import use_idaes_solver_configuration_defaults
import idaes
import idaes.core.util.scaling as iscale
import idaes.core.util as iutil
import ngcc_soec_costing ### changed name of costing module
import ngcc_soec

# %% [markdown]
# ## Make Output Directories
#
# This notebook can produce a large number of output files.  To make it easier to manage, some subdirectories are used to orginize output.  This ensures that the drectories exist.

# %%
def make_directory(path):
    """Make a directory if it doesn't exist"""
    try:
        os.mkdir(path)
    except FileExistsError:
        pass
    
make_directory("data")
make_directory("data_pfds")
make_directory("data_tabulated")

# %% [markdown]
# ## Set Global Solver Options
#
# Setting global solver options applies them to any solver created subsequently, including the ones used for initialization.  The user scaling option disables Ipopt's automatic scaling and allows it to use user provided variable scaling.

# %%
use_idaes_solver_configuration_defaults()
idaes.cfg.ipopt.options.nlp_scaling_method = "user-scaling"
idaes.cfg.ipopt.options.linear_solver = "ma57"
idaes.cfg.ipopt.options.OF_ma57_automatic_scaling = "yes"
idaes.cfg.ipopt.options.ma57_pivtol = 1e-5
idaes.cfg.ipopt.options.ma57_pivtolmax = 0.1
idaes.cfg.ipopt.options.max_iter = 200
solver = pyo.SolverFactory("ipopt")

# %% [markdown]
# ## Create and Initialize the NGCC + SOEC Model

# %%
m = pyo.ConcreteModel()
m.fs = ngcc_soec.NgccSoecFlowsheet(default={"dynamic":False})
iscale.calculate_scaling_factors(m)
m.fs.initialize(
    load_from="ngcc_soec_init.json.gz",
    save_to="ngcc_soec_init.json.gz"
)

m.fs.ngcc.fuel_cost.fix(4.42)
m.fs.ngcc.cap_specific_reboiler_duty.fix(2.4e6)
m.fs.ngcc.cap_fraction.fix(0.97)

res = solver.solve(m, tee=True)

ngcc_soec_costing.add_results_for_costing(m)  ### need to calculate more results to be used by power plant costing
ngcc_soec_costing.get_ngcc_soec_capital_cost(m) ### changed name of costing function

res = solver.solve(m, tee=True)
# Out:
# 2022-07-13 12:28:00 [INFO] idaes.init.fs.ngcc: NGCC load initial from ngcc_init.json.gz
# 2022-07-13 12:28:00 [INFO] idaes.init.fs.soec: SOEC Initialization Starting
# 2022-07-13 12:28:00 [INFO] idaes.init.fs.soec.sweep_compressor.control_volume.properties_in: Starting initialization
# 2022-07-13 12:28:00 [INFO] idaes.init.fs.soec.sweep_compressor.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:00 [INFO] idaes.init.fs.soec.sweep_compressor.control_volume.properties_out: Starting initialization
# 2022-07-13 12:28:00 [INFO] idaes.init.fs.soec.sweep_compressor.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:00 [INFO] idaes.init.fs.soec.sweep_compressor.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:00 [INFO] idaes.init.fs.soec.sweep_compressor.properties_isentropic: Starting initialization
# 2022-07-13 12:28:00 [INFO] idaes.init.fs.soec.sweep_compressor.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:00 [INFO] idaes.init.fs.soec.sweep_compressor.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.sweep_compressor: Initialization Complete: optimal - Optimal Solution Found
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.feed_recycle_mix.feed_state: Starting initialization
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.feed_recycle_mix.feed_state: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.feed_recycle_mix.recycle_state: Starting initialization
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.feed_recycle_mix.recycle_state: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.feed_recycle_mix.mixed_state: Starting initialization
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.feed_recycle_mix.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.feed_recycle_mix.mixed_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.feed_recycle_mix: Initialization Complete: optimal - Optimal Solution Found
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.sweep_recycle_mix.feed_state: Starting initialization
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.sweep_recycle_mix.feed_state: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.sweep_recycle_mix.recycle_state: Starting initialization
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.sweep_recycle_mix.recycle_state: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.sweep_recycle_mix.mixed_state: Starting initialization
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.sweep_recycle_mix.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.sweep_recycle_mix.mixed_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.sweep_recycle_mix: Initialization Complete: optimal - Optimal Solution Found
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.sweep_heater.control_volume.properties_in: Starting initialization
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.sweep_heater.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.sweep_heater.control_volume.properties_out: Starting initialization
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.sweep_heater.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.sweep_heater.control_volume: Initialization Complete
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.sweep_heater: Initialization Complete: optimal - Optimal Solution Found
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.feed_heater.control_volume.properties_in: Starting initialization
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.feed_heater.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.feed_heater.control_volume.properties_out: Starting initialization
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.feed_heater.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:02 [INFO] idaes.init.fs.soec.feed_heater.control_volume: Initialization Complete
# 2022-07-13 12:28:03 [INFO] idaes.init.fs.soec.feed_heater: Initialization Complete: optimal - Optimal Solution Found
# 2022-07-13 12:28:03 [INFO] idaes.init.fs.soec.soec_module.fuel_properties_in: Starting initialization
# 2022-07-13 12:28:03 [INFO] idaes.init.fs.soec.soec_module.fuel_properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:03 [INFO] idaes.init.fs.soec.soec_module.oxygen_properties_in: Starting initialization
# 2022-07-13 12:28:03 [INFO] idaes.init.fs.soec.soec_module.oxygen_properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:06 [INFO] idaes.init.fs.soec.soec_module.solid_oxide_cell: fs.soec.soec_module.solid_oxide_cell initialization completed successfully.
# 2022-07-13 12:28:06 [INFO] idaes.init.fs.soec.soec_module.fuel_properties_out: Starting initialization
# 2022-07-13 12:28:06 [INFO] idaes.init.fs.soec.soec_module.fuel_properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:06 [INFO] idaes.init.fs.soec.soec_module.fuel_properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:06 [INFO] idaes.init.fs.soec.soec_module.oxygen_properties_out: Starting initialization
# 2022-07-13 12:28:06 [INFO] idaes.init.fs.soec.soec_module.oxygen_properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:06 [INFO] idaes.init.fs.soec.soec_module.oxygen_properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.soec_module: fs.soec.soec_module initialization complete.
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.sweep_recycle_split.mixed_state: Starting initialization
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.sweep_recycle_split.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.sweep_recycle_split.out_state: Starting initialization
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.sweep_recycle_split.out_state: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.sweep_recycle_split.out_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.sweep_recycle_split.recycle_state: Starting initialization
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.sweep_recycle_split.recycle_state: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.sweep_recycle_split.recycle_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.sweep_recycle_split: Initialization Step 2 Complete: optimal - Optimal Solution Found
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.feed_recycle_split.mixed_state: Starting initialization
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.feed_recycle_split.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.feed_recycle_split.out_state: Starting initialization
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.feed_recycle_split.out_state: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.feed_recycle_split.out_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.feed_recycle_split.recycle_state: Starting initialization
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.feed_recycle_split.recycle_state: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.feed_recycle_split.recycle_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.feed_recycle_split: Initialization Step 2 Complete: optimal - Optimal Solution Found
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.sweep_hx.shell.properties_in: Starting initialization
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.sweep_hx.shell.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.sweep_hx.shell.properties_out: Starting initialization
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.sweep_hx.shell.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.sweep_hx.shell: Initialization Complete
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.sweep_hx.tube.properties_in: Starting initialization
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.sweep_hx.tube.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.sweep_hx.tube.properties_out: Starting initialization
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.sweep_hx.tube.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:07 [INFO] idaes.init.fs.soec.sweep_hx.tube: Initialization Complete
# 2022-07-13 12:28:08 [INFO] idaes.init.fs.soec.sweep_hx: Initialization Completed, optimal - Optimal Solution Found
# 2022-07-13 12:28:08 [INFO] idaes.init.fs.soec.sweep_turbine.control_volume.properties_in: Starting initialization
# 2022-07-13 12:28:08 [INFO] idaes.init.fs.soec.sweep_turbine.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:08 [INFO] idaes.init.fs.soec.sweep_turbine.control_volume.properties_out: Starting initialization
# 2022-07-13 12:28:08 [INFO] idaes.init.fs.soec.sweep_turbine.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:08 [INFO] idaes.init.fs.soec.sweep_turbine.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:08 [INFO] idaes.init.fs.soec.sweep_turbine.properties_isentropic: Starting initialization
# 2022-07-13 12:28:08 [INFO] idaes.init.fs.soec.sweep_turbine.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:08 [INFO] idaes.init.fs.soec.sweep_turbine.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:09 [INFO] idaes.init.fs.soec.sweep_turbine: Initialization Complete: optimal - Optimal Solution Found
# 2022-07-13 12:28:09 [INFO] idaes.init.fs.soec.feed_hx01.shell.properties_in: Starting initialization
# 2022-07-13 12:28:09 [INFO] idaes.init.fs.soec.feed_hx01.shell.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:09 [INFO] idaes.init.fs.soec.feed_hx01.shell.properties_out: Starting initialization
# 2022-07-13 12:28:09 [INFO] idaes.init.fs.soec.feed_hx01.shell.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:09 [INFO] idaes.init.fs.soec.feed_hx01.shell: Initialization Complete
# 2022-07-13 12:28:09 [INFO] idaes.init.fs.soec.feed_hx01.tube: Initialization Complete
# 2022-07-13 12:28:09 [INFO] idaes.init.fs.soec.feed_hx01: Initialization Completed, optimal - Optimal Solution Found
# 2022-07-13 12:28:09 [INFO] idaes.init.fs.soec.feed_translator.properties_out: Starting initialization
# 2022-07-13 12:28:09 [INFO] idaes.init.fs.soec.feed_translator.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:09 [INFO] idaes.init.fs.soec.feed_translator.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:09 [INFO] idaes.init.fs.soec.feed_translator: Initialization Complete optimal - Optimal Solution Found.
# 2022-07-13 12:28:09 [INFO] idaes.init.fs.soec.water_split: Initialization Complete: optimal - Optimal Solution Found
# 2022-07-13 12:28:09 [INFO] idaes.init.fs.soec.water_heater01.shell.properties_in: Starting initialization
# 2022-07-13 12:28:09 [INFO] idaes.init.fs.soec.water_heater01.shell.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:09 [INFO] idaes.init.fs.soec.water_heater01.shell.properties_out: Starting initialization
# 2022-07-13 12:28:09 [INFO] idaes.init.fs.soec.water_heater01.shell.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:09 [INFO] idaes.init.fs.soec.water_heater01.shell: Initialization Complete
# 2022-07-13 12:28:09 [INFO] idaes.init.fs.soec.water_heater01.tube: Initialization Complete
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.water_heater01: Initialization Completed, optimal - Optimal Solution Found
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.water_heater02.shell.properties_in: Starting initialization
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.water_heater02.shell.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.water_heater02.shell.properties_out: Starting initialization
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.water_heater02.shell.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.water_heater02.shell: Initialization Complete
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.water_heater02.tube: Initialization Complete
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.water_heater02: Initialization Completed, optimal - Optimal Solution Found
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.makeup_mix: Initialization Complete: optimal - Optimal Solution Found
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.h2_precooler.control_volume.properties_in: Starting initialization
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.h2_precooler.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.h2_precooler.control_volume.properties_out: Starting initialization
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.h2_precooler.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.h2_precooler.control_volume: Initialization Complete
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.h2_precooler: Initialization Complete: optimal - Optimal Solution Found
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.cmp01.control_volume.properties_in: Starting initialization
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.cmp01.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.cmp01.control_volume.properties_out: Starting initialization
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.cmp01.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.cmp01.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.cmp01.properties_isentropic: Starting initialization
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.cmp01.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.cmp01.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.cmp01: Initialization Complete: optimal - Optimal Solution Found
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.ic01.control_volume.properties_in: Starting initialization
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.ic01.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.ic01.control_volume.properties_out: Starting initialization
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.ic01.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.ic01.control_volume: Initialization Complete
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.ic01: Initialization Complete: optimal - Optimal Solution Found
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.cmp02.control_volume.properties_in: Starting initialization
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.cmp02.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:10 [INFO] idaes.init.fs.soec.cmp02.control_volume.properties_out: Starting initialization
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.cmp02.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.cmp02.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.cmp02.properties_isentropic: Starting initialization
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.cmp02.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.cmp02.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.cmp02: Initialization Complete: optimal - Optimal Solution Found
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.ic02.control_volume.properties_in: Starting initialization
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.ic02.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.ic02.control_volume.properties_out: Starting initialization
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.ic02.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.ic02.control_volume: Initialization Complete
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.ic02: Initialization Complete: optimal - Optimal Solution Found
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.cmp03.control_volume.properties_in: Starting initialization
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.cmp03.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.cmp03.control_volume.properties_out: Starting initialization
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.cmp03.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.cmp03.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.cmp03.properties_isentropic: Starting initialization
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.cmp03.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.cmp03.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.cmp03: Initialization Complete: optimal - Optimal Solution Found
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.ic03.control_volume.properties_in: Starting initialization
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.ic03.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.ic03.control_volume.properties_out: Starting initialization
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.ic03.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.ic03.control_volume: Initialization Complete
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.ic03: Initialization Complete: optimal - Optimal Solution Found
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.cmp04.control_volume.properties_in: Starting initialization
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.cmp04.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.cmp04.control_volume.properties_out: Starting initialization
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.cmp04.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.cmp04.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.cmp04.properties_isentropic: Starting initialization
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.cmp04.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.cmp04.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2022-07-13 12:28:11 [INFO] idaes.init.fs.soec.cmp04: Initialization Complete: optimal - Optimal Solution Found
# Ipopt 3.13.2: nlp_scaling_method=user-scaling
# tol=1e-06
# linear_solver=ma57
# ma57_pivtol=1e-05
# ma57_pivtolmax=0.1
# max_iter=200
# option_file_name=/var/folders/xf/4r1nvwm50_d1069gf048n6p80000gn/T/tmp0wyhl0r7_ipopt.opt
#
# Using option file "/var/folders/xf/4r1nvwm50_d1069gf048n6p80000gn/T/tmp0wyhl0r7_ipopt.opt".
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:    10712
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     9049
#
# Total number of variables............................:     1746
#                      variables with only lower bounds:      269
#                 variables with lower and upper bounds:      822
#                      variables with only upper bounds:       70
# Total number of equality constraints.................:     1746
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 8.01e+00 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# Reallocating memory for MA57: lfact (181608)
# Reallocating memory for MA57: lfact (197237)
#    1  0.0000000e+00 7.89e+00 7.40e+00  -1.0 1.27e+04    -  5.98e-01 1.55e-02h  7
#    2  0.0000000e+00 7.76e+00 1.28e+01  -1.0 1.23e+04    -  6.32e-01 1.55e-02h  7
#    3  0.0000000e+00 7.64e+00 1.98e+01  -1.0 1.20e+04    -  7.01e-01 1.55e-02h  7
#    4  0.0000000e+00 7.53e+00 2.85e+01  -1.0 1.17e+04    -  8.77e-01 1.55e-02h  7
#    5  0.0000000e+00 7.41e+00 3.74e+01  -1.0 1.14e+04    -  8.98e-01 1.55e-02h  7
#    6  0.0000000e+00 7.29e+00 4.19e+01  -1.0 1.11e+04    -  4.86e-01 1.55e-02h  7
#    7  0.0000000e+00 7.18e+00 4.56e+01  -1.0 1.08e+04    -  4.20e-01 1.55e-02h  7
#    8  0.0000000e+00 6.96e+00 4.83e+01  -1.0 1.05e+04    -  4.02e-01 3.10e-02h  6
#    9  0.0000000e+00 6.74e+00 5.13e+01  -1.0 9.95e+03    -  4.21e-01 3.10e-02h  6
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  0.0000000e+00 6.53e+00 5.46e+01  -1.0 9.63e+03    -  4.49e-01 3.10e-02h  6
#   11  0.0000000e+00 1.90e+01 2.65e+02  -1.0 9.40e+03    -  4.82e-01 9.92e-01w  1
#   12  0.0000000e+00 1.81e+00 1.21e+01  -1.0 4.36e+03    -  9.90e-01 1.00e+00w  1
#   13  0.0000000e+00 6.59e-02 3.73e+01  -1.0 3.19e+02    -  9.92e-01 1.00e+00h  1
#   14  0.0000000e+00 3.87e-05 5.82e-02  -1.0 1.01e+00    -  1.00e+00 1.00e+00h  1
#   15  0.0000000e+00 6.13e-05 9.04e-01  -2.5 1.95e-01    -  1.00e+00 1.00e+00H  1
#   16  0.0000000e+00 6.14e-06 8.05e-02  -2.5 3.03e-02    -  1.00e+00 1.00e+00h  1
#   17  0.0000000e+00 1.36e-06 2.58e-02  -2.5 4.39e-02    -  1.00e+00 1.00e+00h  1
#   18  0.0000000e+00 3.92e-07 4.79e-03  -3.8 8.56e-03    -  1.00e+00 1.00e+00H  1
# Cannot recompute multipliers for feasibility problem.  Error in eq_mult_calculator
#
# Number of Iterations....: 18
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   7.2778519960575377e+03    1.0220639030707678e+05
# Constraint violation....:   3.9209131233106098e-07    3.9209131233106098e-07
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.9209131233106098e-07    1.0220639030707678e+05
#
#
# Number of objective function evaluations             = 114
# Number of objective gradient evaluations             = 19
# Number of equality constraint evaluations            = 114
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 19
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 18
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.470
# Total CPU secs in NLP function evaluations           =      2.191
#
# EXIT: Optimal Solution Found.
# Ipopt 3.13.2: nlp_scaling_method=user-scaling
# tol=1e-06
# linear_solver=ma57
# ma57_pivtol=1e-05
# ma57_pivtolmax=0.1
# max_iter=200
# option_file_name=/var/folders/xf/4r1nvwm50_d1069gf048n6p80000gn/T/tmpmpjsynn9_ipopt.opt
#
# Using option file "/var/folders/xf/4r1nvwm50_d1069gf048n6p80000gn/T/tmpmpjsynn9_ipopt.opt".
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:    10712
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     9049
#
# Total number of variables............................:     1746
#                      variables with only lower bounds:      269
#                 variables with lower and upper bounds:      822
#                      variables with only upper bounds:       70
# Total number of equality constraints.................:     1746
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.16e+01 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# Reallocating memory for MA57: lfact (181587)
# Reallocating memory for MA57: lfact (197216)
#    1  0.0000000e+00 6.53e+00 1.67e+01  -1.0 2.37e+01    -  8.67e-02 9.91e-01h  1
#    2  0.0000000e+00 1.43e-01 1.65e+02  -1.0 1.30e+01    -  8.35e-01 1.00e+00h  1
#    3  0.0000000e+00 4.78e-03 9.03e+01  -1.0 2.33e+00    -  9.35e-01 9.69e-01h  1
#    4  0.0000000e+00 1.79e-04 3.54e+01  -1.0 1.28e+00    -  9.90e-01 1.00e+00f  1
#    5  0.0000000e+00 1.76e-04 2.84e+01  -1.0 2.80e+01    -  9.90e-01 1.00e+00H  1
#    6  0.0000000e+00 4.77e-05 2.27e+01  -1.0 6.17e+00    -  9.90e-01 1.00e+00F  1
#    7  0.0000000e+00 7.69e-06 1.87e-03  -1.0 6.05e-03    -  1.00e+00 1.00e+00h  1
#    8  0.0000000e+00 2.31e-06 5.12e-01  -2.5 1.67e-01    -  1.00e+00 1.00e+00H  1
#    9  0.0000000e+00 3.89e-06 2.45e-02  -2.5 1.45e-02    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  0.0000000e+00 7.78e-07 6.38e+00  -3.8 2.86e-02    -  9.21e-01 1.00e+00h  1
# Cannot recompute multipliers for feasibility problem.  Error in eq_mult_calculator
#
# Number of Iterations....: 10
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   1.2746817669187580e+04    1.9636213139711361e+05
# Constraint violation....:   7.7825250813263002e-07    7.7825250813263002e-07
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   7.7825250813263002e-07    1.9636213139711361e+05
#
#
# Number of objective function evaluations             = 17
# Number of objective gradient evaluations             = 11
# Number of equality constraint evaluations            = 17
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 11
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 10
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.328
# Total CPU secs in NLP function evaluations           =      0.392
#
# EXIT: Optimal Solution Found.
# Ipopt 3.13.2: nlp_scaling_method=user-scaling
# tol=1e-06
# linear_solver=ma57
# ma57_pivtol=1e-05
# ma57_pivtolmax=0.1
# max_iter=200
# option_file_name=/var/folders/xf/4r1nvwm50_d1069gf048n6p80000gn/T/tmp0emyhj7t_ipopt.opt
#
# Using option file "/var/folders/xf/4r1nvwm50_d1069gf048n6p80000gn/T/tmp0emyhj7t_ipopt.opt".
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:    10712
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     9049
#
# Total number of variables............................:     1746
#                      variables with only lower bounds:      269
#                 variables with lower and upper bounds:      822
#                      variables with only upper bounds:       70
# Total number of equality constraints.................:     1746
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.16e+01 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# Reallocating memory for MA57: lfact (178708)
# Reallocating memory for MA57: lfact (193226)
#    1  0.0000000e+00 6.53e+00 1.67e+01  -1.0 2.37e+01    -  8.67e-02 9.91e-01h  1
#    2  0.0000000e+00 1.43e-01 1.65e+02  -1.0 1.30e+01    -  8.35e-01 1.00e+00h  1
#    3  0.0000000e+00 4.78e-03 9.03e+01  -1.0 2.33e+00    -  9.35e-01 9.69e-01h  1
#    4  0.0000000e+00 1.79e-04 3.54e+01  -1.0 1.28e+00    -  9.90e-01 1.00e+00f  1
#    5  0.0000000e+00 1.76e-04 2.84e+01  -1.0 2.80e+01    -  9.90e-01 1.00e+00H  1
#    6  0.0000000e+00 4.77e-05 2.27e+01  -1.0 6.17e+00    -  9.90e-01 1.00e+00F  1
#    7  0.0000000e+00 7.69e-06 1.93e-03  -1.0 6.15e-03    -  1.00e+00 1.00e+00h  1
#    8  0.0000000e+00 2.30e-06 5.14e-01  -2.5 1.67e-01    -  1.00e+00 1.00e+00H  1
#    9  0.0000000e+00 3.90e-06 2.48e-02  -2.5 1.47e-02    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  0.0000000e+00 7.80e-07 6.40e+00  -3.8 2.86e-02    -  9.20e-01 1.00e+00h  1
# Cannot recompute multipliers for feasibility problem.  Error in eq_mult_calculator
#
# Number of Iterations....: 10
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   1.2746817677310246e+04    1.9636213911163973e+05
# Constraint violation....:   7.8003735725708809e-07    7.8003735725708809e-07
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   7.8003735725708809e-07    1.9636213911163973e+05
#
#
# Number of objective function evaluations             = 17
# Number of objective gradient evaluations             = 11
# Number of equality constraint evaluations            = 17
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 11
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 10
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.328
# Total CPU secs in NLP function evaluations           =      0.397
#
# EXIT: Optimal Solution Found.
# Ipopt 3.13.2: nlp_scaling_method=user-scaling
# tol=1e-06
# linear_solver=ma57
# ma57_pivtol=1e-05
# ma57_pivtolmax=0.1
# max_iter=200
# option_file_name=/var/folders/xf/4r1nvwm50_d1069gf048n6p80000gn/T/tmp3op9lbpk_ipopt.opt
#
# Using option file "/var/folders/xf/4r1nvwm50_d1069gf048n6p80000gn/T/tmp3op9lbpk_ipopt.opt".
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:    10809
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     9074
#
# Total number of variables............................:     1759
#                      variables with only lower bounds:      275
#                 variables with lower and upper bounds:      829
#                      variables with only upper bounds:       70
# Total number of equality constraints.................:     1759
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 8.01e+00 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# Reallocating memory for MA57: lfact (206295)
# Reallocating memory for MA57: lfact (224937)
#    1  0.0000000e+00 3.29e-01 4.76e+02  -1.0 7.60e+03    -  5.43e-01 9.90e-01H  1
#    2  0.0000000e+00 4.34e-03 1.60e+01  -1.0 3.10e+02    -  9.89e-01 9.91e-01h  1
#    3  0.0000000e+00 1.13e-06 9.99e+02  -1.0 3.69e+00    -  9.90e-01 1.00e+00h  1
#    4  0.0000000e+00 2.56e-11 8.99e+03  -1.0 1.12e-04    -  9.90e-01 1.00e+00h  1
#
# Number of Iterations....: 4
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   2.5585583932653674e-11    2.5585583932653674e-11
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   2.5585583932653674e-11    2.5585583932653674e-11
#
#
# Number of objective function evaluations             = 8
# Number of objective gradient evaluations             = 5
# Number of equality constraint evaluations            = 8
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 5
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 4
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.184
# Total CPU secs in NLP function evaluations           =      0.169
#
# EXIT: Optimal Solution Found.
# Ipopt 3.13.2: nlp_scaling_method=user-scaling
# tol=1e-06
# linear_solver=ma57
# ma57_pivtol=1e-05
# ma57_pivtolmax=0.1
# max_iter=200
# option_file_name=/var/folders/xf/4r1nvwm50_d1069gf048n6p80000gn/T/tmpvn4srb4v_ipopt.opt
#
# Using option file "/var/folders/xf/4r1nvwm50_d1069gf048n6p80000gn/T/tmpvn4srb4v_ipopt.opt".
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:    10834
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     9089
#
# Total number of variables............................:     1767
#                      variables with only lower bounds:      275
#                 variables with lower and upper bounds:      837
#                      variables with only upper bounds:       70
# Total number of equality constraints.................:     1767
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 8.01e+00 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# Reallocating memory for MA57: lfact (197962)
# Reallocating memory for MA57: lfact (214953)
#    1  0.0000000e+00 9.59e-02 7.30e+00  -1.0 4.35e+02    -  9.32e-01 9.90e-01h  1
#    2  0.0000000e+00 8.73e-04 9.97e-01  -1.0 3.74e+00    -  9.90e-01 9.91e-01h  1
#    3  0.0000000e+00 3.27e-09 9.99e+02  -1.0 3.57e-02    -  9.90e-01 1.00e+00h  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   3.2680644856952767e-09    3.2680644856952767e-09
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.2680644856952767e-09    3.2680644856952767e-09
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 4
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 4
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.149
# Total CPU secs in NLP function evaluations           =      0.078
#
# EXIT: Optimal Solution Found.
# Ipopt 3.13.2: nlp_scaling_method=user-scaling
# tol=1e-06
# linear_solver=ma57
# ma57_pivtol=1e-05
# ma57_pivtolmax=0.1
# max_iter=200
# option_file_name=/var/folders/xf/4r1nvwm50_d1069gf048n6p80000gn/T/tmpzlac9boe_ipopt.opt
#
# Using option file "/var/folders/xf/4r1nvwm50_d1069gf048n6p80000gn/T/tmpzlac9boe_ipopt.opt".
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:    10850
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     9098
#
# Total number of variables............................:     1772
#                      variables with only lower bounds:      275
#                 variables with lower and upper bounds:      842
#                      variables with only upper bounds:       70
# Total number of equality constraints.................:     1772
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 8.01e+00 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# Reallocating memory for MA57: lfact (198195)
# Reallocating memory for MA57: lfact (215187)
#    1  0.0000000e+00 1.74e-01 8.12e+00  -1.0 9.12e+02    -  9.03e-01 9.90e-01h  1
#    2  0.0000000e+00 1.67e-03 1.01e+00  -1.0 3.65e+01    -  9.90e-01 9.91e-01h  1
#    3  0.0000000e+00 2.36e-08 9.99e+02  -1.0 3.27e-01    -  9.90e-01 1.00e+00h  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   2.3636371271279437e-08    2.3636371271279437e-08
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   2.3636371271279437e-08    2.3636371271279437e-08
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 4
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 4
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.155
# Total CPU secs in NLP function evaluations           =      0.080
#
# EXIT: Optimal Solution Found.
# 2022-07-13 12:28:37 [INFO] idaes.init.fs.soec: SOEC initialization complete
# 2022-07-13 12:28:38 [INFO] idaes.init.fs.soec: Initialization saved to soec_init.json.gz
# Ipopt 3.13.2: nlp_scaling_method=user-scaling
# tol=1e-06
# linear_solver=ma57
# ma57_pivtol=1e-05
# ma57_pivtolmax=0.1
# max_iter=200
# option_file_name=/var/folders/xf/4r1nvwm50_d1069gf048n6p80000gn/T/tmpmtiafifv_ipopt.opt
#
# Using option file "/var/folders/xf/4r1nvwm50_d1069gf048n6p80000gn/T/tmpmtiafifv_ipopt.opt".
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:    18517
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:    14416
#
# Total number of variables............................:     4177
#                      variables with only lower bounds:      362
#                 variables with lower and upper bounds:     2290
#                      variables with only upper bounds:       70
# Total number of equality constraints.................:     4177
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 3.50e+01 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# Reallocating memory for MA57: lfact (335819)
#    1  0.0000000e+00 3.49e-01 8.68e+03  -1.0 2.71e+03    -  9.81e-01 9.90e-01h  1
#    2  0.0000000e+00 3.20e-03 3.50e+02  -1.0 2.26e+03    -  9.89e-01 9.91e-01h  1
#    3  0.0000000e+00 1.16e-04 1.03e+03  -1.0 4.07e+02    -  9.90e-01 1.00e+00h  1
#    4  0.0000000e+00 1.03e-05 9.00e+03  -1.0 3.55e+01    -  9.90e-01 1.00e+00h  1
#    5  0.0000000e+00 9.10e-07 4.53e+01  -1.0 3.14e+00    -  9.95e-01 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   9.0953117529157801e-07    9.0953117529157801e-07
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   9.0953117529157801e-07    9.0953117529157801e-07
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.364
# Total CPU secs in NLP function evaluations           =      0.873
#
# EXIT: Optimal Solution Found.
# Ipopt 3.13.2: nlp_scaling_method=user-scaling
# tol=1e-06
# linear_solver=ma57
# ma57_pivtol=1e-05
# ma57_pivtolmax=0.1
# max_iter=200
# option_file_name=/var/folders/xf/4r1nvwm50_d1069gf048n6p80000gn/T/tmpnz2zrssz_ipopt.opt
#
# Using option file "/var/folders/xf/4r1nvwm50_d1069gf048n6p80000gn/T/tmpnz2zrssz_ipopt.opt".
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:    18518
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:    14417
#
# Total number of variables............................:     4177
#                      variables with only lower bounds:      362
#                 variables with lower and upper bounds:     2290
#                      variables with only upper bounds:       70
# Total number of equality constraints.................:     4177
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 3.50e+01 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# Reallocating memory for MA57: lfact (334983)
#    1  0.0000000e+00 3.39e+01 4.45e+04  -1.0 1.64e+06    -  8.79e-01 2.94e-02h  6
#    2  0.0000000e+00 3.29e+01 6.89e+04  -1.0 1.59e+06    -  9.62e-01 2.95e-02h  6
#    3  0.0000000e+00 3.20e+01 8.14e+04  -1.0 1.54e+06    -  9.76e-01 2.95e-02h  6
#    4  0.0000000e+00 2.45e+01 4.96e+06  -1.0 1.49e+06    -  9.89e-01 9.90e-01H  1
#    5  0.0000000e+00 5.38e-01 5.64e+05  -1.0 3.62e+04    -  9.90e-01 9.89e-01h  1
#    6  0.0000000e+00 1.57e-02 1.41e+03  -1.0 4.00e+03    -  9.92e-01 1.00e+00h  1
#    7  0.0000000e+00 7.90e-05 7.11e+03  -1.0 2.28e+02    -  9.92e-01 1.00e+00h  1
#    8  0.0000000e+00 5.55e-06 9.77e-02  -1.0 1.56e+01    -  1.00e+00 1.00e+00h  1
#    9  0.0000000e+00 3.88e-07 1.12e+00  -3.8 1.09e+00    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 9
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   3.8782624053879111e-07    3.8782624053879111e-07
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.8782624053879111e-07    3.8782624053879111e-07
#
#
# Number of objective function evaluations             = 40
# Number of objective gradient evaluations             = 10
# Number of equality constraint evaluations            = 40
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 10
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 9
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.539
# Total CPU secs in NLP function evaluations           =      4.613
#
# EXIT: Optimal Solution Found.

# %%
def display_pfd():
    print("\n\nGas Turbine Section\n")
    display(SVG(m.fs.ngcc.gt.write_pfd()))
    print("\n\nHRSG Section\n")
    display(SVG(m.fs.ngcc.hrsg.write_pfd()))
    print("\n\nSteam Turbine Section\n")
    display(SVG(m.fs.ngcc.st.write_pfd()))
    print("\n\nSOEC Section\n")
    display(SVG(m.fs.soec.write_pfd()))

# %%
m.fs.ngcc.net_power_mw.display()
m.fs.ngcc.st.steam_turbine.throttle_valve[1].deltaP.display()

# %%
decision_vars = []
def make_decision_var(v, lb, ub):
    v.unfix()
    v.setlb(lb)
    v.setub(ub)
    decision_vars.append(v)

# Add constraints for optimization
m.fs.ngcc.st.steam_turbine.throttle_valve[1].deltaP.setub(-1e5)
m.fs.soec.sweep_recycle_split.mixed_state[0].mole_frac_comp["O2"].setub(0.35)
m.fs.soec.feed_recycle_split.mixed_state[0].mole_frac_comp["H2O"].setlb(0.20)
m.fs.soec.sweep_recycle_split.mixed_state[0].temperature.setub(1030)
m.fs.soec.feed_recycle_split.mixed_state[0].temperature.setub(1030)
m.fs.ngcc.st.steam_turbine_lp_split.mixed_state[0].pressure.setlb(2.9e5)

@m.fs.Constraint(m.fs.time)
def makeup_water_constraint(b, t):
    return m.fs.soec.water_pump.inlet.flow_mol[t] == m.fs.soec.feed_hx01.tube_inlet.flow_mol[t]

# make sure the delta T on the hydrogen side is 40K or less (it's 
# squared so one constraint covers both positive and negative delta T)
@m.fs.Constraint(m.fs.time)
def delta_T_h_constraint(b, t):
    return (
        m.fs.soec.feed_heater.control_volume.properties_out[t].temperature -
        m.fs.soec.feed_recycle_split.mixed_state[t].temperature
    )**2/100 <= 16

# make sure the delta T on the oxygen side is 40K or less
@m.fs.Constraint(m.fs.time)
def delta_T_o_constraint(b, t):
    return (
        m.fs.soec.sweep_heater.control_volume.properties_out[t].temperature -
        m.fs.soec.sweep_recycle_split.mixed_state[t].temperature
    )**2/100 <= 16

# make sure the oxygen inlet and hydrogen outlet are 40K or less apart
@m.fs.Constraint(m.fs.time)
def delta_T_1_constraint(b, t):
    return (
        m.fs.soec.sweep_heater.control_volume.properties_out[t].temperature -
        m.fs.soec.feed_recycle_split.mixed_state[t].temperature
    )**2/100 <= 16

# make sure the hydrogen inlet and oxygen outlet are 40K or less apart
@m.fs.Constraint(m.fs.time)
def delta_T_2_constraint(b, t):
    return (
        m.fs.soec.feed_heater.control_volume.properties_out[t].temperature -
        m.fs.soec.sweep_recycle_split.mixed_state[t].temperature
    )**2/100 <= 16

@m.fs.Constraint(m.fs.time)
def average_current_density_constraint(b, t):
    return m.fs.soec.soec_module.solid_oxide_cell.average_current_density[0]/1000 >= -8

m.fs.soec.water_pump.inlet.flow_mol.unfix()
make_decision_var(m.fs.soec.sweep_recycle_split.split_fraction[0, "out"], 0.50, 0.97)
make_decision_var(m.fs.soec.feed_recycle_split.split_fraction[0, "out"], 0.50, 0.98) 
make_decision_var(m.fs.soec.water_split.split_fraction[0, "outlet1"], 0.3, 0.7)
make_decision_var(m.fs.soec.sweep_compressor.inlet.flow_mol[0], 100, 8000)
make_decision_var(m.fs.soec.soec_module.potential_cell[0], 1.26, 1.38)
make_decision_var(m.fs.soec.feed_heater.control_volume.properties_out[0].temperature, 900, 1020)
make_decision_var(m.fs.soec.sweep_heater.control_volume.properties_out[0].temperature, 900, 1020)
make_decision_var(m.fs.soec.sweep_heater.control_volume.properties_out[0].temperature, 900, 1020)
make_decision_var(m.fs.soec.soec_module.number_cells, 1e6, 2e6)
make_decision_var(m.fs.soec.sweep_hx.area, 2000, 7000)
make_decision_var(m.fs.soec.feed_hx01.area, 2000, 7000)
make_decision_var(m.fs.soec.water_heater01.area, 2000, 7000)
make_decision_var(m.fs.soec.water_heater02.area, 2000, 7000)

m.fs.obj_design = pyo.Objective(
    expr=(
        m.fs.ngcc.total_variable_cost_rate[0] + 
        m.fs.soec.variable_makeup_water_cost[0] +
        (m.fs.ngcc.net_power[0] + m.fs.soec.total_electric_power[0])/1e6 * 100 +
        m.fs.costing.total_TPC*1e6 * 1.093 * 0.0707 * 1.341 / 365 / 24 # anualized cap. + fixed O&M for SOEC part
    )/1000
)

# %%
res = solver.solve(m, tee=True)

# %%
display_pfd()

# %%
# Print freed decision vars
for v in decision_vars:
    print(f"{v} {pyo.value(v)}")

print("\n")
print("------------------------------------------")
print("Fixed Costs for Optimized Design")
print("------------------------------------------")

tpc = pyo.value(m.fs.costing.total_TPC*1e6)  ### the main costing block is now under fs
tasc = pyo.value(m.fs.costing.total_TPC*1e6)*1.21*1.093
ac = tasc*0.0707
print(f"TPC = {tpc}")
print(f"TASC = {tasc}")
print(f"Annualized TASC (MM$/yr) = {ac/1e6}")

# Parameters
n_op = 8
hourly_rate = 38.50
labor_burden = 30

# Fixed O&M components
annual_op_labor = n_op * hourly_rate * 8760 * (1 + labor_burden/100)/1e6
maint_labor = tpc * 0.4 * 0.019 / 1e6
maint_material = tpc * 0.6 * 0.019 / 1e6
admin_labor = 0.25*(annual_op_labor + maint_labor)
prop_tax_ins = 0.02*tpc/1e6
soec_replace = pyo.value(4.2765*m.fs.soec.soec_module.number_cells)/1e6

print("Fixed O&M Costs")
print(f"annual_op_labor (MM$/yr) = {annual_op_labor}")
print(f"maint_labor (MM$/yr) = {maint_labor}")
print(f"maint_material (MM$/yr) = {maint_material}")
print(f"admin_labor (MM$/yr) = {admin_labor}")
print(f"prop_tax_ins (MM$/yr) = {prop_tax_ins}")
print(f"soec_replace (MM$/yr) = {soec_replace}")
total_fixed = annual_op_labor + maint_labor + maint_material + admin_labor + prop_tax_ins + soec_replace
print(f"Annualized Fixed O&M = {total_fixed}")

print("\n")
print("------------------------------------------")
print("SOEC TPC Breakdown")
print("------------------------------------------")

ngcc_soec_costing.display_capital_costs(m) ### added new function to display the costs from power plant costing

# %%
# lock in the design vars
m.fs.soec.soec_module.number_cells.fix()
m.fs.soec.sweep_hx.area.fix()
m.fs.soec.feed_hx01.area.fix()
m.fs.soec.water_heater01.area.fix()
m.fs.soec.water_heater02.area.fix()

m.fs.obj_design.deactivate()
m.fs.obj_op = pyo.Objective(
    expr=(
        m.fs.ngcc.total_variable_cost_rate[0] + 
        m.fs.soec.variable_makeup_water_cost[0] +
        (m.fs.ngcc.net_power[0] + m.fs.soec.total_electric_power[0])/1e6 * 100
    )
)
res = solver.solve(m, tee=True)

# %%
m.fs.ngcc.gt.write_pfd(fname="data_pfds/gt_soec_base.svg")
m.fs.ngcc.hrsg.write_pfd(fname="data_pfds/hrsg_soec_base.svg")
m.fs.ngcc.st.write_pfd(fname="data_pfds/st_soec_base.svg")
m.fs.soec.write_pfd(fname="data_pfds/soec_soec_base.svg")
display_pfd()

m.fs.ngcc.gt.streams_dataframe().to_csv("data_tabulated/ngcc_soec_stream_5kg_gt.csv")
m.fs.ngcc.st.steam_streams_dataframe().to_csv("data_tabulated/ngcc_soec_stream_5kg_st.csv")
m.fs.ngcc.hrsg.steam_streams_dataframe().to_csv("data_tabulated/ngcc_soec_stream_5kg_hrsg_steam.csv")
m.fs.ngcc.hrsg.flue_gas_streams_dataframe().to_csv("data_tabulated/ngcc_soec_stream_5kg_hrsg_gas.csv")
m.fs.soec.streams_dataframe().to_csv("data_tabulated/ngcc_soec_stream_5kg_soec.csv")

# %%
run_samples = True
df = None
if run_samples:
    import pandas as pd
    gt_powers = np.linspace(480., 305., int((480. - 305.)/5.0) + 1).tolist()
    hp_powers = np.linspace(5, 0.75, int((5. - 0.75)/0.25) + 1).tolist()
    
    df = pd.DataFrame(columns=m.fs.tags_output.table_heading())
    i = 1
    for gp in gt_powers:
        gpstr = str(math.ceil(gp))
        m.fs.ngcc.gt.gt_power.fix(-gp*1e6)
        save_to_last = None
        for hp in hp_powers:
            if hp > 5.001 - 0.25*(480 - gp)/30:
                continue
            m.fs.soec.hydrogen_product_rate.fix(hp)
            hpstr = str(math.ceil(hp*1000))
            save_to = f"data/ngcc_soec_{gpstr}_{hpstr}.json.gz"
            print(save_to)
            if os.path.exists(save_to):
                iutil.from_json(m, fname=save_to, wts=iutil.StoreSpec(suffix=False))                    
                if save_to_last is None:
                    save_to_last = save_to
            else:
                res = solver.solve(m, tee=True)
                if not pyo.check_optimal_termination(res):
                    print("Fail")
                    break
                if save_to_last is None:
                    save_to_last = save_to
                iutil.to_json(m, fname=save_to)
            print(f"Overall net power: {-pyo.value(m.fs.ngcc.net_power[0] + m.fs.soec.total_electric_power[0])/1e6} MW")
            #for v in decision_vars:
            #    print(f"{v} {pyo.value(v)}")
            df.loc[i] = m.fs.tags_output.table_row(numeric=True)
            i += 1
        # go to the closest part of the start of the next series.
        iutil.from_json(m, fname=save_to_last, wts=iutil.StoreSpec(suffix=False))

# %%
if df is not None:
    df.to_csv("data_tabulated/ngcc_soec.csv")
