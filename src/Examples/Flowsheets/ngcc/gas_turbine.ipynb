# %%
import pyomo.environ as pyo
import gas_turbine as gt
import idaes.core.util.scaling as iscale

# %%
m = pyo.ConcreteModel()

# %%
m.fs = gt.GasTurbineFlowsheet(default={"dynamic":False})

# %%
m.fs.initialize()
# Out:
# 2022-02-15 13:32:36 [INFO] idaes.init.fs.feed_air1.properties: Starting initialization
# 2022-02-15 13:32:36 [INFO] idaes.init.fs.feed_air1.properties: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:36 [INFO] idaes.init.fs.feed_air1.properties: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:36 [INFO] idaes.init.fs.feed_air1: Initialization Complete.
# 2022-02-15 13:32:36 [INFO] idaes.init.fs.feed_fuel1.properties: Starting initialization
# 2022-02-15 13:32:36 [INFO] idaes.init.fs.feed_fuel1.properties: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:36 [INFO] idaes.init.fs.feed_fuel1.properties: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:36 [INFO] idaes.init.fs.feed_fuel1: Initialization Complete.
# 2022-02-15 13:32:36 [INFO] idaes.init.fs.vsv.control_volume.properties_in: Starting initialization
# 2022-02-15 13:32:36 [INFO] idaes.init.fs.vsv.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:36 [INFO] idaes.init.fs.vsv.control_volume.properties_out: Starting initialization
# 2022-02-15 13:32:36 [INFO] idaes.init.fs.vsv.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:36 [INFO] idaes.init.fs.vsv.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:37 [INFO] idaes.init.fs.vsv: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 13:32:37 [INFO] idaes.init.fs.cmp1.control_volume.properties_in: Starting initialization
# 2022-02-15 13:32:38 [INFO] idaes.init.fs.cmp1.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:38 [INFO] idaes.init.fs.cmp1.control_volume.properties_out: Starting initialization
# 2022-02-15 13:32:38 [INFO] idaes.init.fs.cmp1.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:38 [INFO] idaes.init.fs.cmp1.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:38 [INFO] idaes.init.fs.cmp1.properties_isentropic: Starting initialization
# 2022-02-15 13:32:38 [INFO] idaes.init.fs.cmp1.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:38 [INFO] idaes.init.fs.cmp1.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:44 [INFO] idaes.init.fs.cmp1: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 13:32:44 [INFO] idaes.init.fs.splt1.mixed_state: Starting initialization
# 2022-02-15 13:32:44 [INFO] idaes.init.fs.splt1.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:44 [INFO] idaes.init.fs.splt1.air04_state: Starting initialization
# 2022-02-15 13:32:44 [INFO] idaes.init.fs.splt1.air04_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:44 [INFO] idaes.init.fs.splt1.air04_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:44 [INFO] idaes.init.fs.splt1.air05_state: Starting initialization
# 2022-02-15 13:32:44 [INFO] idaes.init.fs.splt1.air05_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:44 [INFO] idaes.init.fs.splt1.air05_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:44 [INFO] idaes.init.fs.splt1.air07_state: Starting initialization
# 2022-02-15 13:32:44 [INFO] idaes.init.fs.splt1.air07_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:44 [INFO] idaes.init.fs.splt1.air07_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:44 [INFO] idaes.init.fs.splt1.air09_state: Starting initialization
# 2022-02-15 13:32:44 [INFO] idaes.init.fs.splt1.air09_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:44 [INFO] idaes.init.fs.splt1.air09_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:45 [INFO] idaes.init.fs.splt1: Initialization Step 2 Complete: optimal - Optimal Solution Found
# 2022-02-15 13:32:45 [INFO] idaes.init.fs.inject_translator.properties_in: Starting initialization
# 2022-02-15 13:32:45 [INFO] idaes.init.fs.inject_translator.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:45 [INFO] idaes.init.fs.inject_translator.properties_out: Starting initialization
# 2022-02-15 13:32:45 [INFO] idaes.init.fs.inject_translator.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:45 [INFO] idaes.init.fs.inject_translator.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:45 [INFO] idaes.init.fs.inject_translator: Initialization Complete optimal - Optimal Solution Found.
# 2022-02-15 13:32:45 [INFO] idaes.init.fs.inject1.gas_state: Starting initialization
# 2022-02-15 13:32:45 [INFO] idaes.init.fs.inject1.gas_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:45 [INFO] idaes.init.fs.inject1.air_state: Starting initialization
# 2022-02-15 13:32:45 [INFO] idaes.init.fs.inject1.air_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:45 [INFO] idaes.init.fs.inject1.mixed_state: Starting initialization
# 2022-02-15 13:32:46 [INFO] idaes.init.fs.inject1.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:46 [INFO] idaes.init.fs.inject1.mixed_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:49 [INFO] idaes.init.fs.inject1: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 13:32:49 [INFO] idaes.init.fs.cmb1.control_volume.properties_in: Starting initialization
# 2022-02-15 13:32:49 [INFO] idaes.init.fs.cmb1.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:49 [INFO] idaes.init.fs.cmb1.control_volume.properties_out: Starting initialization
# 2022-02-15 13:32:50 [INFO] idaes.init.fs.cmb1.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:50 [INFO] idaes.init.fs.cmb1.control_volume.reactions: Initialization Complete.
# 2022-02-15 13:32:50 [INFO] idaes.init.fs.cmb1.control_volume: Initialization Complete
# 2022-02-15 13:32:53 [INFO] idaes.init.fs.cmb1: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 13:32:53 [INFO] idaes.init.fs.flue_translator.properties_in: Starting initialization
# 2022-02-15 13:32:53 [INFO] idaes.init.fs.flue_translator.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:53 [INFO] idaes.init.fs.flue_translator.properties_out: Starting initialization
# 2022-02-15 13:32:53 [INFO] idaes.init.fs.flue_translator.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:53 [INFO] idaes.init.fs.flue_translator.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:53 [INFO] idaes.init.fs.flue_translator: Initialization Complete optimal - Optimal Solution Found.
# 2022-02-15 13:32:53 [INFO] idaes.init.fs.gts1.control_volume.properties_in: Starting initialization
# 2022-02-15 13:32:53 [INFO] idaes.init.fs.gts1.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:53 [INFO] idaes.init.fs.gts1.control_volume.properties_out: Starting initialization
# 2022-02-15 13:32:53 [INFO] idaes.init.fs.gts1.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:53 [INFO] idaes.init.fs.gts1.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:53 [INFO] idaes.init.fs.gts1.properties_isentropic: Starting initialization
# 2022-02-15 13:32:53 [INFO] idaes.init.fs.gts1.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:32:53 [INFO] idaes.init.fs.gts1.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:03 [INFO] idaes.init.fs.gts1: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 13:33:03 [INFO] idaes.init.fs.valve01.control_volume.properties_in: Starting initialization
# 2022-02-15 13:33:04 [INFO] idaes.init.fs.valve01.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:04 [INFO] idaes.init.fs.valve01.control_volume.properties_out: Starting initialization
# 2022-02-15 13:33:04 [INFO] idaes.init.fs.valve01.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:04 [INFO] idaes.init.fs.valve01.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:05 [INFO] idaes.init.fs.valve01: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 13:33:05 [INFO] idaes.init.fs.translator1.properties_in: Starting initialization
# 2022-02-15 13:33:05 [INFO] idaes.init.fs.translator1.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:05 [INFO] idaes.init.fs.translator1.properties_out: Starting initialization
# 2022-02-15 13:33:05 [INFO] idaes.init.fs.translator1.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:05 [INFO] idaes.init.fs.translator1.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:05 [INFO] idaes.init.fs.translator1: Initialization Complete optimal - Optimal Solution Found.
# 2022-02-15 13:33:05 [INFO] idaes.init.fs.mx1.gas_state: Starting initialization
# 2022-02-15 13:33:05 [INFO] idaes.init.fs.mx1.gas_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:05 [INFO] idaes.init.fs.mx1.air_state: Starting initialization
# 2022-02-15 13:33:05 [INFO] idaes.init.fs.mx1.air_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:05 [INFO] idaes.init.fs.mx1.mixed_state: Starting initialization
# 2022-02-15 13:33:06 [INFO] idaes.init.fs.mx1.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:06 [INFO] idaes.init.fs.mx1.mixed_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:07 [INFO] idaes.init.fs.mx1: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 13:33:07 [INFO] idaes.init.fs.gts2.control_volume.properties_in: Starting initialization
# 2022-02-15 13:33:07 [INFO] idaes.init.fs.gts2.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:07 [INFO] idaes.init.fs.gts2.control_volume.properties_out: Starting initialization
# 2022-02-15 13:33:08 [INFO] idaes.init.fs.gts2.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:08 [INFO] idaes.init.fs.gts2.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:08 [INFO] idaes.init.fs.gts2.properties_isentropic: Starting initialization
# 2022-02-15 13:33:08 [INFO] idaes.init.fs.gts2.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:08 [INFO] idaes.init.fs.gts2.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:18 [INFO] idaes.init.fs.gts2: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 13:33:18 [INFO] idaes.init.fs.valve02.control_volume.properties_in: Starting initialization
# 2022-02-15 13:33:18 [INFO] idaes.init.fs.valve02.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:18 [INFO] idaes.init.fs.valve02.control_volume.properties_out: Starting initialization
# 2022-02-15 13:33:18 [INFO] idaes.init.fs.valve02.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:18 [INFO] idaes.init.fs.valve02.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:19 [INFO] idaes.init.fs.valve02: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 13:33:19 [INFO] idaes.init.fs.translator2.properties_in: Starting initialization
# 2022-02-15 13:33:19 [INFO] idaes.init.fs.translator2.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:19 [INFO] idaes.init.fs.translator2.properties_out: Starting initialization
# 2022-02-15 13:33:19 [INFO] idaes.init.fs.translator2.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:19 [INFO] idaes.init.fs.translator2.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:20 [INFO] idaes.init.fs.translator2: Initialization Complete optimal - Optimal Solution Found.
# 2022-02-15 13:33:20 [INFO] idaes.init.fs.mx2.gas_state: Starting initialization
# 2022-02-15 13:33:20 [INFO] idaes.init.fs.mx2.gas_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:20 [INFO] idaes.init.fs.mx2.air_state: Starting initialization
# 2022-02-15 13:33:20 [INFO] idaes.init.fs.mx2.air_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:20 [INFO] idaes.init.fs.mx2.mixed_state: Starting initialization
# 2022-02-15 13:33:20 [INFO] idaes.init.fs.mx2.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:20 [INFO] idaes.init.fs.mx2.mixed_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:22 [INFO] idaes.init.fs.mx2: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 13:33:22 [INFO] idaes.init.fs.gts3.control_volume.properties_in: Starting initialization
# 2022-02-15 13:33:22 [INFO] idaes.init.fs.gts3.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:22 [INFO] idaes.init.fs.gts3.control_volume.properties_out: Starting initialization
# 2022-02-15 13:33:22 [INFO] idaes.init.fs.gts3.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:22 [INFO] idaes.init.fs.gts3.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:22 [INFO] idaes.init.fs.gts3.properties_isentropic: Starting initialization
# 2022-02-15 13:33:22 [INFO] idaes.init.fs.gts3.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:22 [INFO] idaes.init.fs.gts3.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:33 [INFO] idaes.init.fs.gts3: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 13:33:33 [INFO] idaes.init.fs.valve03.control_volume.properties_in: Starting initialization
# 2022-02-15 13:33:33 [INFO] idaes.init.fs.valve03.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:33 [INFO] idaes.init.fs.valve03.control_volume.properties_out: Starting initialization
# 2022-02-15 13:33:33 [INFO] idaes.init.fs.valve03.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:33 [INFO] idaes.init.fs.valve03.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:35 [INFO] idaes.init.fs.valve03: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 13:33:35 [INFO] idaes.init.fs.translator3.properties_in: Starting initialization
# 2022-02-15 13:33:35 [INFO] idaes.init.fs.translator3.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:35 [INFO] idaes.init.fs.translator3.properties_out: Starting initialization
# 2022-02-15 13:33:35 [INFO] idaes.init.fs.translator3.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:35 [INFO] idaes.init.fs.translator3.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:35 [INFO] idaes.init.fs.translator3: Initialization Complete optimal - Optimal Solution Found.
# 2022-02-15 13:33:35 [INFO] idaes.init.fs.mx3.gas_state: Starting initialization
# 2022-02-15 13:33:35 [INFO] idaes.init.fs.mx3.gas_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:35 [INFO] idaes.init.fs.mx3.air_state: Starting initialization
# 2022-02-15 13:33:36 [INFO] idaes.init.fs.mx3.air_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:36 [INFO] idaes.init.fs.mx3.mixed_state: Starting initialization
# 2022-02-15 13:33:36 [INFO] idaes.init.fs.mx3.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:36 [INFO] idaes.init.fs.mx3.mixed_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:37 [INFO] idaes.init.fs.mx3: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 13:33:37 [INFO] idaes.init.fs.exhaust_1.properties: Starting initialization
# 2022-02-15 13:33:37 [INFO] idaes.init.fs.exhaust_1.properties: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:37 [INFO] idaes.init.fs.exhaust_1.properties: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 13:33:37 [INFO] idaes.init.fs.exhaust_1: Initialization Complete.
# Ipopt 3.13.2: nlp_scaling_method=gradient-based
# tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     2655
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     2033
#
# Total number of variables............................:      913
#                      variables with only lower bounds:       52
#                 variables with lower and upper bounds:      810
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      913
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 3.06e+08 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 3.11e+06 1.56e+02  -1.0 4.01e+08    -  9.89e-01 9.90e-01h  1
#    2  0.0000000e+00 3.10e+04 2.90e+01  -1.0 4.08e+06    -  9.90e-01 9.90e-01h  1
#    3  0.0000000e+00 5.60e+00 9.81e+02  -1.0 4.04e+04    -  9.90e-01 1.00e+00h  1
#    4  0.0000000e+00 2.98e-07 8.84e+04  -1.0 7.28e+00    -  9.91e-01 1.00e+00h  1
# Cannot recompute multipliers for feasibility problem.  Error in eq_mult_calculator
#
# Number of Iterations....: 4
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   9.8265573446717747e+06    9.8265573446717747e+06
# Constraint violation....:   7.2759576141834259e-11    2.9802322387695312e-07
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   7.2759576141834259e-11    9.8265573446717747e+06
#
#
# Number of objective function evaluations             = 5
# Number of objective gradient evaluations             = 5
# Number of equality constraint evaluations            = 5
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 5
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 4
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.182
# Total CPU secs in NLP function evaluations           =      0.729
#
# EXIT: Optimal Solution Found.
# Ipopt 3.13.2: nlp_scaling_method=gradient-based
# tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     2658
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     2019
#
# Total number of variables............................:      913
#                      variables with only lower bounds:       52
#                 variables with lower and upper bounds:      812
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      913
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 3.06e+08 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 1.27e+07 6.58e+05  -1.0 2.51e+07    -  9.02e-01 9.79e-01h  1
#    2  0.0000000e+00 1.39e+05 1.10e+05  -1.0 1.59e+06    -  9.87e-01 9.90e-01h  1
#    3  0.0000000e+00 7.44e+02 6.03e+02  -1.0 1.23e+04    -  9.90e-01 9.95e-01h  1
#    4  0.0000000e+00 2.63e-05 6.29e+04  -1.0 6.52e+01    -  9.90e-01 1.00e+00h  1
# Cannot recompute multipliers for feasibility problem.  Error in eq_mult_calculator
#
# Number of Iterations....: 4
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   6.4325891320737358e+06    6.4325891320737358e+06
# Constraint violation....:   6.9396606531822908e-10    2.6315450668334961e-05
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   6.9396606531822908e-10    6.4325891320737358e+06
#
#
# Number of objective function evaluations             = 5
# Number of objective gradient evaluations             = 5
# Number of equality constraint evaluations            = 5
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 5
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 4
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.348
# Total CPU secs in NLP function evaluations           =      0.728
#
# EXIT: Optimal Solution Found.
