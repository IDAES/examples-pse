# %% [markdown]
# # Gas Turbine Flowsheet

# %% [markdown]
# ## Imports

# %%
from IPython.core.display import SVG
import idaes
import pyomo.environ as pyo
import gas_turbine as gt
import idaes.core.util.scaling as iscale
from idaes.core.solvers import use_idaes_solver_configuration_defaults

# %% [markdown]
# ## Create Model

# %%
m = pyo.ConcreteModel()
m.fs = gt.GasTurbineFlowsheet(default={"dynamic":False})
iscale.calculate_scaling_factors(m)

# %% [markdown]
# ## Setup the solver

# %%
use_idaes_solver_configuration_defaults()
idaes.cfg.ipopt.options.nlp_scaling_method = "user-scaling"

# %% [markdown]
# ## Initialize Model
#
# The product of the initialize method for this flowsheet is a gas turbine set to produce 480 MW.  The model is also set up for pressure-driven flow.
# The power settings will adjust the compressor so that flow through the turbine produces 480 MW.  The amount of fuel injected is set such that the
# turbine exhaust is 910 K.

# %%
m.fs.initialize()
# Out:
# 2022-02-28 10:34:12 [INFO] idaes.init.fs.feed_air1.properties: Starting initialization
# 2022-02-28 10:34:12 [INFO] idaes.init.fs.feed_air1.properties: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:12 [INFO] idaes.init.fs.feed_air1.properties: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:12 [INFO] idaes.init.fs.feed_air1: Initialization Complete.
# 2022-02-28 10:34:12 [INFO] idaes.init.fs.feed_fuel1.properties: Starting initialization
# 2022-02-28 10:34:12 [INFO] idaes.init.fs.feed_fuel1.properties: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:12 [INFO] idaes.init.fs.feed_fuel1.properties: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:12 [INFO] idaes.init.fs.feed_fuel1: Initialization Complete.
# 2022-02-28 10:34:12 [INFO] idaes.init.fs.vsv.control_volume.properties_in: Starting initialization
# 2022-02-28 10:34:12 [INFO] idaes.init.fs.vsv.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:12 [INFO] idaes.init.fs.vsv.control_volume.properties_out: Starting initialization
# 2022-02-28 10:34:13 [INFO] idaes.init.fs.vsv.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:13 [INFO] idaes.init.fs.vsv.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:14 [INFO] idaes.init.fs.vsv: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-28 10:34:14 [INFO] idaes.init.fs.cmp1.control_volume.properties_in: Starting initialization
# 2022-02-28 10:34:14 [INFO] idaes.init.fs.cmp1.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:14 [INFO] idaes.init.fs.cmp1.control_volume.properties_out: Starting initialization
# 2022-02-28 10:34:14 [INFO] idaes.init.fs.cmp1.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:14 [INFO] idaes.init.fs.cmp1.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:14 [INFO] idaes.init.fs.cmp1.properties_isentropic: Starting initialization
# 2022-02-28 10:34:14 [INFO] idaes.init.fs.cmp1.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:14 [INFO] idaes.init.fs.cmp1.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:19 [INFO] idaes.init.fs.cmp1: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-28 10:34:19 [INFO] idaes.init.fs.splt1.mixed_state: Starting initialization
# 2022-02-28 10:34:19 [INFO] idaes.init.fs.splt1.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:19 [INFO] idaes.init.fs.splt1.air04_state: Starting initialization
# 2022-02-28 10:34:20 [INFO] idaes.init.fs.splt1.air04_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:20 [INFO] idaes.init.fs.splt1.air04_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:20 [INFO] idaes.init.fs.splt1.air05_state: Starting initialization
# 2022-02-28 10:34:20 [INFO] idaes.init.fs.splt1.air05_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:20 [INFO] idaes.init.fs.splt1.air05_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:20 [INFO] idaes.init.fs.splt1.air07_state: Starting initialization
# 2022-02-28 10:34:20 [INFO] idaes.init.fs.splt1.air07_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:20 [INFO] idaes.init.fs.splt1.air07_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:20 [INFO] idaes.init.fs.splt1.air09_state: Starting initialization
# 2022-02-28 10:34:20 [INFO] idaes.init.fs.splt1.air09_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:20 [INFO] idaes.init.fs.splt1.air09_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:20 [INFO] idaes.init.fs.splt1: Initialization Step 2 Complete: optimal - Optimal Solution Found
# 2022-02-28 10:34:20 [INFO] idaes.init.fs.inject_translator.properties_in: Starting initialization
# 2022-02-28 10:34:21 [INFO] idaes.init.fs.inject_translator.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:21 [INFO] idaes.init.fs.inject_translator.properties_out: Starting initialization
# 2022-02-28 10:34:21 [INFO] idaes.init.fs.inject_translator.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:21 [INFO] idaes.init.fs.inject_translator.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:21 [INFO] idaes.init.fs.inject_translator: Initialization Complete optimal - Optimal Solution Found.
# 2022-02-28 10:34:21 [INFO] idaes.init.fs.ng_preheat.shell: Initialization Complete
# 2022-02-28 10:34:21 [INFO] idaes.init.fs.ng_preheat.tube.properties_in: Starting initialization
# 2022-02-28 10:34:21 [INFO] idaes.init.fs.ng_preheat.tube.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:21 [INFO] idaes.init.fs.ng_preheat.tube.properties_out: Starting initialization
# 2022-02-28 10:34:21 [INFO] idaes.init.fs.ng_preheat.tube.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:21 [INFO] idaes.init.fs.ng_preheat.tube: Initialization Complete
# 2022-02-28 10:34:27 [INFO] idaes.init.fs.ng_preheat: Initialization Completed, optimal - Optimal Solution Found
# 2022-02-28 10:34:27 [INFO] idaes.init.fs.inject1.gas_state: Starting initialization
# 2022-02-28 10:34:27 [INFO] idaes.init.fs.inject1.gas_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:27 [INFO] idaes.init.fs.inject1.air_state: Starting initialization
# 2022-02-28 10:34:27 [INFO] idaes.init.fs.inject1.air_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:27 [INFO] idaes.init.fs.inject1.mixed_state: Starting initialization
# 2022-02-28 10:34:27 [INFO] idaes.init.fs.inject1.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:27 [INFO] idaes.init.fs.inject1.mixed_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:31 [INFO] idaes.init.fs.inject1: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-28 10:34:31 [INFO] idaes.init.fs.cmb1.control_volume.properties_in: Starting initialization
# 2022-02-28 10:34:32 [INFO] idaes.init.fs.cmb1.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:32 [INFO] idaes.init.fs.cmb1.control_volume.properties_out: Starting initialization
# 2022-02-28 10:34:32 [INFO] idaes.init.fs.cmb1.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:32 [INFO] idaes.init.fs.cmb1.control_volume.reactions: Initialization Complete.
# 2022-02-28 10:34:32 [INFO] idaes.init.fs.cmb1.control_volume: Initialization Complete
# 2022-02-28 10:34:35 [INFO] idaes.init.fs.cmb1: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-28 10:34:35 [INFO] idaes.init.fs.flue_translator.properties_in: Starting initialization
# 2022-02-28 10:34:35 [INFO] idaes.init.fs.flue_translator.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:35 [INFO] idaes.init.fs.flue_translator.properties_out: Starting initialization
# 2022-02-28 10:34:35 [INFO] idaes.init.fs.flue_translator.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:35 [INFO] idaes.init.fs.flue_translator.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:35 [INFO] idaes.init.fs.flue_translator: Initialization Complete optimal - Optimal Solution Found.
# 2022-02-28 10:34:35 [INFO] idaes.init.fs.gts1.control_volume.properties_in: Starting initialization
# 2022-02-28 10:34:35 [INFO] idaes.init.fs.gts1.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:35 [INFO] idaes.init.fs.gts1.control_volume.properties_out: Starting initialization
# 2022-02-28 10:34:35 [INFO] idaes.init.fs.gts1.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:35 [INFO] idaes.init.fs.gts1.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:35 [INFO] idaes.init.fs.gts1.properties_isentropic: Starting initialization
# 2022-02-28 10:34:36 [INFO] idaes.init.fs.gts1.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:36 [INFO] idaes.init.fs.gts1.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:44 [INFO] idaes.init.fs.gts1: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-28 10:34:44 [INFO] idaes.init.fs.valve01.control_volume.properties_in: Starting initialization
# 2022-02-28 10:34:44 [INFO] idaes.init.fs.valve01.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:44 [INFO] idaes.init.fs.valve01.control_volume.properties_out: Starting initialization
# 2022-02-28 10:34:44 [INFO] idaes.init.fs.valve01.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:44 [INFO] idaes.init.fs.valve01.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:45 [INFO] idaes.init.fs.valve01: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-28 10:34:45 [INFO] idaes.init.fs.translator1.properties_in: Starting initialization
# 2022-02-28 10:34:46 [INFO] idaes.init.fs.translator1.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:46 [INFO] idaes.init.fs.translator1.properties_out: Starting initialization
# 2022-02-28 10:34:46 [INFO] idaes.init.fs.translator1.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:46 [INFO] idaes.init.fs.translator1.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:46 [INFO] idaes.init.fs.translator1: Initialization Complete optimal - Optimal Solution Found.
# 2022-02-28 10:34:46 [INFO] idaes.init.fs.mx1.gas_state: Starting initialization
# 2022-02-28 10:34:46 [INFO] idaes.init.fs.mx1.gas_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:46 [INFO] idaes.init.fs.mx1.air_state: Starting initialization
# 2022-02-28 10:34:46 [INFO] idaes.init.fs.mx1.air_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:46 [INFO] idaes.init.fs.mx1.mixed_state: Starting initialization
# 2022-02-28 10:34:46 [INFO] idaes.init.fs.mx1.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:46 [INFO] idaes.init.fs.mx1.mixed_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:48 [INFO] idaes.init.fs.mx1: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-28 10:34:48 [INFO] idaes.init.fs.gts2.control_volume.properties_in: Starting initialization
# 2022-02-28 10:34:48 [INFO] idaes.init.fs.gts2.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:48 [INFO] idaes.init.fs.gts2.control_volume.properties_out: Starting initialization
# 2022-02-28 10:34:48 [INFO] idaes.init.fs.gts2.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:48 [INFO] idaes.init.fs.gts2.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:48 [INFO] idaes.init.fs.gts2.properties_isentropic: Starting initialization
# 2022-02-28 10:34:48 [INFO] idaes.init.fs.gts2.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:48 [INFO] idaes.init.fs.gts2.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:57 [INFO] idaes.init.fs.gts2: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-28 10:34:57 [INFO] idaes.init.fs.valve02.control_volume.properties_in: Starting initialization
# 2022-02-28 10:34:57 [INFO] idaes.init.fs.valve02.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:57 [INFO] idaes.init.fs.valve02.control_volume.properties_out: Starting initialization
# 2022-02-28 10:34:58 [INFO] idaes.init.fs.valve02.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:58 [INFO] idaes.init.fs.valve02.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:59 [INFO] idaes.init.fs.valve02: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-28 10:34:59 [INFO] idaes.init.fs.translator2.properties_in: Starting initialization
# 2022-02-28 10:34:59 [INFO] idaes.init.fs.translator2.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:59 [INFO] idaes.init.fs.translator2.properties_out: Starting initialization
# 2022-02-28 10:34:59 [INFO] idaes.init.fs.translator2.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:59 [INFO] idaes.init.fs.translator2.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:59 [INFO] idaes.init.fs.translator2: Initialization Complete optimal - Optimal Solution Found.
# 2022-02-28 10:34:59 [INFO] idaes.init.fs.mx2.gas_state: Starting initialization
# 2022-02-28 10:34:59 [INFO] idaes.init.fs.mx2.gas_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:59 [INFO] idaes.init.fs.mx2.air_state: Starting initialization
# 2022-02-28 10:34:59 [INFO] idaes.init.fs.mx2.air_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:34:59 [INFO] idaes.init.fs.mx2.mixed_state: Starting initialization
# 2022-02-28 10:35:00 [INFO] idaes.init.fs.mx2.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:35:00 [INFO] idaes.init.fs.mx2.mixed_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:35:01 [INFO] idaes.init.fs.mx2: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-28 10:35:01 [INFO] idaes.init.fs.gts3.control_volume.properties_in: Starting initialization
# 2022-02-28 10:35:01 [INFO] idaes.init.fs.gts3.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:35:01 [INFO] idaes.init.fs.gts3.control_volume.properties_out: Starting initialization
# 2022-02-28 10:35:02 [INFO] idaes.init.fs.gts3.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:35:02 [INFO] idaes.init.fs.gts3.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:35:02 [INFO] idaes.init.fs.gts3.properties_isentropic: Starting initialization
# 2022-02-28 10:35:02 [INFO] idaes.init.fs.gts3.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:35:02 [INFO] idaes.init.fs.gts3.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:35:11 [INFO] idaes.init.fs.gts3: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-28 10:35:11 [INFO] idaes.init.fs.valve03.control_volume.properties_in: Starting initialization
# 2022-02-28 10:35:11 [INFO] idaes.init.fs.valve03.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:35:11 [INFO] idaes.init.fs.valve03.control_volume.properties_out: Starting initialization
# 2022-02-28 10:35:11 [INFO] idaes.init.fs.valve03.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:35:11 [INFO] idaes.init.fs.valve03.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:35:12 [INFO] idaes.init.fs.valve03: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-28 10:35:12 [INFO] idaes.init.fs.translator3.properties_in: Starting initialization
# 2022-02-28 10:35:12 [INFO] idaes.init.fs.translator3.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:35:12 [INFO] idaes.init.fs.translator3.properties_out: Starting initialization
# 2022-02-28 10:35:12 [INFO] idaes.init.fs.translator3.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:35:12 [INFO] idaes.init.fs.translator3.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:35:13 [INFO] idaes.init.fs.translator3: Initialization Complete optimal - Optimal Solution Found.
# 2022-02-28 10:35:13 [INFO] idaes.init.fs.mx3.gas_state: Starting initialization
# 2022-02-28 10:35:13 [INFO] idaes.init.fs.mx3.gas_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:35:13 [INFO] idaes.init.fs.mx3.air_state: Starting initialization
# 2022-02-28 10:35:13 [INFO] idaes.init.fs.mx3.air_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:35:13 [INFO] idaes.init.fs.mx3.mixed_state: Starting initialization
# 2022-02-28 10:35:13 [INFO] idaes.init.fs.mx3.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:35:13 [INFO] idaes.init.fs.mx3.mixed_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:35:15 [INFO] idaes.init.fs.mx3: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-28 10:35:15 [INFO] idaes.init.fs.exhaust_1.properties: Starting initialization
# 2022-02-28 10:35:15 [INFO] idaes.init.fs.exhaust_1.properties: Property initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:35:15 [INFO] idaes.init.fs.exhaust_1.properties: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-28 10:35:15 [INFO] idaes.init.fs.exhaust_1: Initialization Complete.
# Ipopt 3.13.2: nlp_scaling_method=user-scaling
# tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     2809
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     2196
#
# Total number of variables............................:      966
#                      variables with only lower bounds:       54
#                 variables with lower and upper bounds:      856
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      966
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 3.17e+01 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 3.17e-01 7.70e+00  -1.0 4.02e+08    -  9.90e-01 9.90e-01h  1
#    2  0.0000000e+00 2.86e-03 9.01e+00  -1.0 4.09e+06    -  1.00e+00 9.91e-01h  1
#    3  0.0000000e+00 5.99e-11 8.58e-01  -1.7 3.69e+04    -  1.00e+00 1.00e+00h  1
# Cannot recompute multipliers for feasibility problem.  Error in eq_mult_calculator
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   2.0879336176375622e+04    1.9108195006697555e+06
# Constraint violation....:   5.9928131701373195e-11    5.9928131701373195e-11
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   5.9928131701373195e-11    1.9108195006697555e+06
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 4
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 4
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.226
# Total CPU secs in NLP function evaluations           =      0.566
#
# EXIT: Optimal Solution Found.
# Ipopt 3.13.2: nlp_scaling_method=user-scaling
# tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     2812
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     2182
#
# Total number of variables............................:      966
#                      variables with only lower bounds:       54
#                 variables with lower and upper bounds:      858
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      966
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 3.17e+01 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 4.09e-01 9.32e+00  -1.0 5.73e+00    -  9.27e-01 9.77e-01h  1
#    2  0.0000000e+00 4.70e-03 8.22e+00  -1.0 5.70e-01    -  9.91e-01 9.90e-01h  1
#    3  0.0000000e+00 6.08e-08 1.01e+00  -1.7 5.32e-03    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   6.0792329643801177e-08    6.0792329643801177e-08
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   6.0792329643801177e-08    6.0792329643801177e-08
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 4
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 4
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.193
# Total CPU secs in NLP function evaluations           =      0.626
#
# EXIT: Optimal Solution Found.

# %% [markdown]
# ## Show the stream table
#
# The componet fractions that are ``NaN`` (not a number) represent compoenent that are not present in a stream.

# %%
streams_df = m.fs.streams_dataframe()
display(streams_df)
# Out:
#        mass flow (kg/s) mole flow (kmol/s) mole percent Ar (%)  \
# air01       1008.736793           34.95831                0.92
# air02       1008.736793           34.95831                0.92
# air03       1008.736793           34.95831                0.92
# air04a       921.365239          31.930403                0.92
# air04b       921.365239          31.930403                0.92
# air05          63.64969           2.205814                0.92
# air06a         63.64969           2.205814                0.92
# air06b         63.64969           2.205814                0.92
# air07         13.992453           0.484916                0.92
# air08a        13.992453           0.484916                0.92
# air08b        13.992453           0.484916                0.92
# air09          9.729411           0.337178                0.92
# air10a         9.729411           0.337178                0.92
# air10b         9.729411           0.337178                0.92
# fuel01         25.04429           1.452417                 0.0
# fuel02         25.04429           1.452417                 0.0
# g01          946.409529           33.38282            0.879973
# g02a         946.534698           33.42494            0.878864
# g02b         946.534698           33.42494            0.878864
# g03          946.534698           33.42494            0.878864
# g04         1010.184388          35.630754             0.88141
# g05         1010.184388          35.630754             0.88141
# g06         1024.176841           36.11567            0.881929
# g07         1024.176841           36.11567            0.881929
# g08         1033.906252          36.452848            0.882281
# st01          15.312988               0.85                 NaN
# st02          15.312988               0.85                 NaN
#
#        mole percent C2H6 (%) mole percent C3H8 (%) mole percent C4H10 (%)  \
# air01                    NaN                   NaN                    NaN
# air02                    NaN                   NaN                    NaN
# air03                    NaN                   NaN                    NaN
# air04a                   NaN                   NaN                    NaN
# air04b                   0.0                   0.0                    0.0
# air05                    NaN                   NaN                    NaN
# air06a                   NaN                   NaN                    NaN
# air06b                   NaN                   NaN                    NaN
# air07                    NaN                   NaN                    NaN
# air08a                   NaN                   NaN                    NaN
# air08b                   NaN                   NaN                    NaN
# air09                    NaN                   NaN                    NaN
# air10a                   NaN                   NaN                    NaN
# air10b                   NaN                   NaN                    NaN
# fuel01                   3.2                   0.7                    0.4
# fuel02                   3.2                   0.7                    0.4
# g01                 0.139225              0.030456               0.017403
# g02a                     0.0                   0.0                    0.0
# g02b                     NaN                   NaN                    NaN
# g03                      NaN                   NaN                    NaN
# g04                      NaN                   NaN                    NaN
# g05                      NaN                   NaN                    NaN
# g06                      NaN                   NaN                    NaN
# g07                      NaN                   NaN                    NaN
# g08                      NaN                   NaN                    NaN
# st01                     NaN                   NaN                    NaN
# st02                     NaN                   NaN                    NaN
#
#        mole percent CH4 (%) mole percent CO2 (%) mole percent H2O (%)  \
# air01                   NaN                 0.03                 0.99
# air02                   NaN                 0.03                 0.99
# air03                   NaN                 0.03                 0.99
# air04a                  NaN                 0.03                 0.99
# air04b                  0.0                 0.03                 0.99
# air05                   NaN                 0.03                 0.99
# air06a                  NaN                 0.03                 0.99
# air06b                  NaN                 0.03                 0.99
# air07                   NaN                 0.03                 0.99
# air08a                  NaN                 0.03                 0.99
# air08b                  NaN                 0.03                 0.99
# air09                   NaN                 0.03                 0.99
# air10a                  NaN                 0.03                 0.99
# air10b                  NaN                 0.03                 0.99
# fuel01                 93.1                  1.0                  0.0
# fuel02                 93.1                  1.0                  0.0
# g01                4.050588             0.072203             0.946927
# g02a                    0.0             4.556472             9.662427
# g02b                    NaN             4.556472             9.662427
# g03                     NaN             4.556472             9.662427
# g04                     NaN             4.276249             9.125538
# g05                     NaN             4.276249             9.125538
# g06                     NaN             4.219236             9.016304
# g07                     NaN             4.219236             9.016304
# g08                     NaN             4.180487             8.942063
# st01                    NaN                  NaN                  100
# st02                    NaN                  NaN                  100
#
#        mole percent N2 (%) mole percent O2 (%) pressure (bar) temperature (K)  \
# air01                77.32               20.74        1.03421          288.15
# air02                77.32               20.74         0.9965      288.138322
# air03                77.32               20.74      17.438745      674.552096
# air04a               77.32               20.74      17.438745      674.552096
# air04b               77.32               20.74      17.438745      674.552096
# air05                77.32               20.74      17.438745      674.552096
# air06a               77.32               20.74        6.52565       674.53593
# air06b               77.32               20.74        6.52565       674.53593
# air07                77.32               20.74      17.438745      674.552096
# air08a               77.32               20.74       2.580946      674.525969
# air08b               77.32               20.74       2.580946      674.525969
# air09                77.32               20.74      17.438745      674.552096
# air10a               77.32               20.74        1.02594      674.521431
# air10b               77.32               20.74        1.02594      674.521431
# fuel01                 1.6                 0.0        31.0264         310.928
# fuel02                 1.6                 0.0        31.0264      442.554475
# g01              74.025579           19.837646      17.438745      658.113898
# g02a             73.932297            10.96994      16.566807     1658.592936
# g02b             73.932297            10.96994      16.566807     1658.592936
# g03              73.932297            10.96994        6.52565     1381.868152
# g04              74.142021           11.574781        6.52565     1342.142468
# g05              74.142021           11.574781       2.580946     1111.946248
# g06              74.184691            11.69784       2.580946     1106.530004
# g07              74.184691            11.69784        1.02594       912.06272
# g08              74.213692           11.781478        1.02594             910
# st01                   NaN                 NaN           42.0      455.980309
# st02                   NaN                 NaN           42.0       330.55689
#
#        volumetric flow (m**3/s)
# air01                809.211946
# air02                839.823917
# air03                113.037622
# air04a               103.246889
# air04b               103.246889
# air05                  7.132494
# air06a                18.995727
# air06b                18.995727
# air07                  1.567975
# air08a                10.545437
# air08b                10.545437
# air09                  1.090264
# air10a                18.437576
# air10b                18.437576
# fuel01                 1.134546
# fuel02                 1.699126
# g01                  105.303133
# g02a                 278.991556
# g02b                 278.991556
# g03                  589.267039
# g04                  610.117653
# g05                 1277.107291
# g06                 1288.185492
# g07                 2670.221286
# g08                 2689.056357
# st01                   0.017282
# st02                   0.015526

# %% [markdown]
# ## Show the PFD
