# %% [markdown]
# # Gas Turbine Flowsheet

# %% [markdown]
# ## Imports

# %%
from IPython.core.display import SVG
import idaes
import pyomo.environ as pyo
import gas_turbine as gt
import idaes.core.util.scaling as iscale
from idaes.core.solvers import use_idaes_solver_configuration_defaults

# %% [markdown]
# ## Create Model

# %%
m = pyo.ConcreteModel()
m.fs = gt.GasTurbineFlowsheet(default={"dynamic":False})
iscale.calculate_scaling_factors(m)

# %% [markdown]
# ## Setup the solver

# %%
use_idaes_solver_configuration_defaults()
idaes.cfg.ipopt.options.nlp_scaling_method = "user-scaling"

# %% [markdown]
# ## Initialize Model
#
# The product of the initialize method for this flowsheet is a gas turbine set to produce 480 MW.  The model is also set up for pressure-driven flow.
# The power settings will adjust the compressor so that flow through the turbine produces 480 MW.  The amount of fuel injected is set such that the
# turbine exhaust is 910 K.

# %%
m.fs.initialize()
# Out:
# 2022-02-15 18:28:35 [INFO] idaes.init.fs.feed_air1.properties: Starting initialization
# 2022-02-15 18:28:35 [INFO] idaes.init.fs.feed_air1.properties: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:35 [INFO] idaes.init.fs.feed_air1.properties: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:35 [INFO] idaes.init.fs.feed_air1: Initialization Complete.
# 2022-02-15 18:28:35 [INFO] idaes.init.fs.feed_fuel1.properties: Starting initialization
# 2022-02-15 18:28:35 [INFO] idaes.init.fs.feed_fuel1.properties: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:35 [INFO] idaes.init.fs.feed_fuel1.properties: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:35 [INFO] idaes.init.fs.feed_fuel1: Initialization Complete.
# 2022-02-15 18:28:35 [INFO] idaes.init.fs.vsv.control_volume.properties_in: Starting initialization
# 2022-02-15 18:28:35 [INFO] idaes.init.fs.vsv.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:35 [INFO] idaes.init.fs.vsv.control_volume.properties_out: Starting initialization
# 2022-02-15 18:28:35 [INFO] idaes.init.fs.vsv.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:35 [INFO] idaes.init.fs.vsv.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:37 [INFO] idaes.init.fs.vsv: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 18:28:37 [INFO] idaes.init.fs.cmp1.control_volume.properties_in: Starting initialization
# 2022-02-15 18:28:37 [INFO] idaes.init.fs.cmp1.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:37 [INFO] idaes.init.fs.cmp1.control_volume.properties_out: Starting initialization
# 2022-02-15 18:28:37 [INFO] idaes.init.fs.cmp1.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:37 [INFO] idaes.init.fs.cmp1.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:37 [INFO] idaes.init.fs.cmp1.properties_isentropic: Starting initialization
# 2022-02-15 18:28:37 [INFO] idaes.init.fs.cmp1.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:37 [INFO] idaes.init.fs.cmp1.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:43 [INFO] idaes.init.fs.cmp1: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 18:28:43 [INFO] idaes.init.fs.splt1.mixed_state: Starting initialization
# 2022-02-15 18:28:43 [INFO] idaes.init.fs.splt1.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:43 [INFO] idaes.init.fs.splt1.air04_state: Starting initialization
# 2022-02-15 18:28:43 [INFO] idaes.init.fs.splt1.air04_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:43 [INFO] idaes.init.fs.splt1.air04_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:43 [INFO] idaes.init.fs.splt1.air05_state: Starting initialization
# 2022-02-15 18:28:43 [INFO] idaes.init.fs.splt1.air05_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:43 [INFO] idaes.init.fs.splt1.air05_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:44 [INFO] idaes.init.fs.splt1.air07_state: Starting initialization
# 2022-02-15 18:28:44 [INFO] idaes.init.fs.splt1.air07_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:44 [INFO] idaes.init.fs.splt1.air07_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:44 [INFO] idaes.init.fs.splt1.air09_state: Starting initialization
# 2022-02-15 18:28:44 [INFO] idaes.init.fs.splt1.air09_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:44 [INFO] idaes.init.fs.splt1.air09_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:44 [INFO] idaes.init.fs.splt1: Initialization Step 2 Complete: optimal - Optimal Solution Found
# 2022-02-15 18:28:44 [INFO] idaes.init.fs.inject_translator.properties_in: Starting initialization
# 2022-02-15 18:28:44 [INFO] idaes.init.fs.inject_translator.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:44 [INFO] idaes.init.fs.inject_translator.properties_out: Starting initialization
# 2022-02-15 18:28:44 [INFO] idaes.init.fs.inject_translator.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:44 [INFO] idaes.init.fs.inject_translator.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:44 [INFO] idaes.init.fs.inject_translator: Initialization Complete optimal - Optimal Solution Found.
# 2022-02-15 18:28:44 [INFO] idaes.init.fs.inject1.gas_state: Starting initialization
# 2022-02-15 18:28:44 [INFO] idaes.init.fs.inject1.gas_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:44 [INFO] idaes.init.fs.inject1.air_state: Starting initialization
# 2022-02-15 18:28:45 [INFO] idaes.init.fs.inject1.air_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:45 [INFO] idaes.init.fs.inject1.mixed_state: Starting initialization
# 2022-02-15 18:28:45 [INFO] idaes.init.fs.inject1.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:45 [INFO] idaes.init.fs.inject1.mixed_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:49 [INFO] idaes.init.fs.inject1: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 18:28:49 [INFO] idaes.init.fs.cmb1.control_volume.properties_in: Starting initialization
# 2022-02-15 18:28:50 [INFO] idaes.init.fs.cmb1.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:50 [INFO] idaes.init.fs.cmb1.control_volume.properties_out: Starting initialization
# 2022-02-15 18:28:50 [INFO] idaes.init.fs.cmb1.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:50 [INFO] idaes.init.fs.cmb1.control_volume.reactions: Initialization Complete.
# 2022-02-15 18:28:50 [INFO] idaes.init.fs.cmb1.control_volume: Initialization Complete
# 2022-02-15 18:28:54 [INFO] idaes.init.fs.cmb1: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 18:28:54 [INFO] idaes.init.fs.flue_translator.properties_in: Starting initialization
# 2022-02-15 18:28:54 [INFO] idaes.init.fs.flue_translator.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:54 [INFO] idaes.init.fs.flue_translator.properties_out: Starting initialization
# 2022-02-15 18:28:54 [INFO] idaes.init.fs.flue_translator.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:54 [INFO] idaes.init.fs.flue_translator.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:54 [INFO] idaes.init.fs.flue_translator: Initialization Complete optimal - Optimal Solution Found.
# 2022-02-15 18:28:54 [INFO] idaes.init.fs.gts1.control_volume.properties_in: Starting initialization
# 2022-02-15 18:28:54 [INFO] idaes.init.fs.gts1.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:54 [INFO] idaes.init.fs.gts1.control_volume.properties_out: Starting initialization
# 2022-02-15 18:28:54 [INFO] idaes.init.fs.gts1.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:54 [INFO] idaes.init.fs.gts1.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:54 [INFO] idaes.init.fs.gts1.properties_isentropic: Starting initialization
# 2022-02-15 18:28:55 [INFO] idaes.init.fs.gts1.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:28:55 [INFO] idaes.init.fs.gts1.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:05 [INFO] idaes.init.fs.gts1: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 18:29:05 [INFO] idaes.init.fs.valve01.control_volume.properties_in: Starting initialization
# 2022-02-15 18:29:05 [INFO] idaes.init.fs.valve01.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:05 [INFO] idaes.init.fs.valve01.control_volume.properties_out: Starting initialization
# 2022-02-15 18:29:05 [INFO] idaes.init.fs.valve01.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:05 [INFO] idaes.init.fs.valve01.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:07 [INFO] idaes.init.fs.valve01: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 18:29:07 [INFO] idaes.init.fs.translator1.properties_in: Starting initialization
# 2022-02-15 18:29:07 [INFO] idaes.init.fs.translator1.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:07 [INFO] idaes.init.fs.translator1.properties_out: Starting initialization
# 2022-02-15 18:29:07 [INFO] idaes.init.fs.translator1.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:07 [INFO] idaes.init.fs.translator1.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:07 [INFO] idaes.init.fs.translator1: Initialization Complete optimal - Optimal Solution Found.
# 2022-02-15 18:29:07 [INFO] idaes.init.fs.mx1.gas_state: Starting initialization
# 2022-02-15 18:29:07 [INFO] idaes.init.fs.mx1.gas_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:07 [INFO] idaes.init.fs.mx1.air_state: Starting initialization
# 2022-02-15 18:29:07 [INFO] idaes.init.fs.mx1.air_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:07 [INFO] idaes.init.fs.mx1.mixed_state: Starting initialization
# 2022-02-15 18:29:07 [INFO] idaes.init.fs.mx1.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:07 [INFO] idaes.init.fs.mx1.mixed_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:09 [INFO] idaes.init.fs.mx1: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 18:29:09 [INFO] idaes.init.fs.gts2.control_volume.properties_in: Starting initialization
# 2022-02-15 18:29:09 [INFO] idaes.init.fs.gts2.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:09 [INFO] idaes.init.fs.gts2.control_volume.properties_out: Starting initialization
# 2022-02-15 18:29:10 [INFO] idaes.init.fs.gts2.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:10 [INFO] idaes.init.fs.gts2.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:10 [INFO] idaes.init.fs.gts2.properties_isentropic: Starting initialization
# 2022-02-15 18:29:10 [INFO] idaes.init.fs.gts2.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:10 [INFO] idaes.init.fs.gts2.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:19 [INFO] idaes.init.fs.gts2: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 18:29:19 [INFO] idaes.init.fs.valve02.control_volume.properties_in: Starting initialization
# 2022-02-15 18:29:20 [INFO] idaes.init.fs.valve02.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:20 [INFO] idaes.init.fs.valve02.control_volume.properties_out: Starting initialization
# 2022-02-15 18:29:20 [INFO] idaes.init.fs.valve02.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:20 [INFO] idaes.init.fs.valve02.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:21 [INFO] idaes.init.fs.valve02: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 18:29:21 [INFO] idaes.init.fs.translator2.properties_in: Starting initialization
# 2022-02-15 18:29:21 [INFO] idaes.init.fs.translator2.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:21 [INFO] idaes.init.fs.translator2.properties_out: Starting initialization
# 2022-02-15 18:29:21 [INFO] idaes.init.fs.translator2.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:21 [INFO] idaes.init.fs.translator2.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:21 [INFO] idaes.init.fs.translator2: Initialization Complete optimal - Optimal Solution Found.
# 2022-02-15 18:29:21 [INFO] idaes.init.fs.mx2.gas_state: Starting initialization
# 2022-02-15 18:29:21 [INFO] idaes.init.fs.mx2.gas_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:21 [INFO] idaes.init.fs.mx2.air_state: Starting initialization
# 2022-02-15 18:29:22 [INFO] idaes.init.fs.mx2.air_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:22 [INFO] idaes.init.fs.mx2.mixed_state: Starting initialization
# 2022-02-15 18:29:22 [INFO] idaes.init.fs.mx2.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:22 [INFO] idaes.init.fs.mx2.mixed_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:23 [INFO] idaes.init.fs.mx2: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 18:29:23 [INFO] idaes.init.fs.gts3.control_volume.properties_in: Starting initialization
# 2022-02-15 18:29:24 [INFO] idaes.init.fs.gts3.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:24 [INFO] idaes.init.fs.gts3.control_volume.properties_out: Starting initialization
# 2022-02-15 18:29:24 [INFO] idaes.init.fs.gts3.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:24 [INFO] idaes.init.fs.gts3.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:24 [INFO] idaes.init.fs.gts3.properties_isentropic: Starting initialization
# 2022-02-15 18:29:24 [INFO] idaes.init.fs.gts3.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:24 [INFO] idaes.init.fs.gts3.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:34 [INFO] idaes.init.fs.gts3: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 18:29:34 [INFO] idaes.init.fs.valve03.control_volume.properties_in: Starting initialization
# 2022-02-15 18:29:34 [INFO] idaes.init.fs.valve03.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:34 [INFO] idaes.init.fs.valve03.control_volume.properties_out: Starting initialization
# 2022-02-15 18:29:34 [INFO] idaes.init.fs.valve03.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:34 [INFO] idaes.init.fs.valve03.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:36 [INFO] idaes.init.fs.valve03: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 18:29:36 [INFO] idaes.init.fs.translator3.properties_in: Starting initialization
# 2022-02-15 18:29:36 [INFO] idaes.init.fs.translator3.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:36 [INFO] idaes.init.fs.translator3.properties_out: Starting initialization
# 2022-02-15 18:29:36 [INFO] idaes.init.fs.translator3.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:36 [INFO] idaes.init.fs.translator3.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:36 [INFO] idaes.init.fs.translator3: Initialization Complete optimal - Optimal Solution Found.
# 2022-02-15 18:29:36 [INFO] idaes.init.fs.mx3.gas_state: Starting initialization
# 2022-02-15 18:29:36 [INFO] idaes.init.fs.mx3.gas_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:36 [INFO] idaes.init.fs.mx3.air_state: Starting initialization
# 2022-02-15 18:29:36 [INFO] idaes.init.fs.mx3.air_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:36 [INFO] idaes.init.fs.mx3.mixed_state: Starting initialization
# 2022-02-15 18:29:37 [INFO] idaes.init.fs.mx3.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:37 [INFO] idaes.init.fs.mx3.mixed_state: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:38 [INFO] idaes.init.fs.mx3: Initialization Complete: optimal - Optimal Solution Found
# 2022-02-15 18:29:38 [INFO] idaes.init.fs.exhaust_1.properties: Starting initialization
# 2022-02-15 18:29:38 [INFO] idaes.init.fs.exhaust_1.properties: Property initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:38 [INFO] idaes.init.fs.exhaust_1.properties: Property package initialization: optimal - Optimal Solution Found.
# 2022-02-15 18:29:38 [INFO] idaes.init.fs.exhaust_1: Initialization Complete.
# Ipopt 3.13.2: nlp_scaling_method=user-scaling
# tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     2655
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     2033
#
# Total number of variables............................:      913
#                      variables with only lower bounds:       52
#                 variables with lower and upper bounds:      810
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      913
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 3.17e+01 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 3.17e-01 4.08e-01  -1.0 4.01e+08    -  9.90e-01 9.90e-01h  1
#    2  0.0000000e+00 2.86e-03 9.01e+00  -1.0 4.08e+06    -  1.00e+00 9.91e-01h  1
#    3  0.0000000e+00 5.99e-11 2.08e-02  -1.7 3.69e+04    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   5.9928132372300359e-11    5.9928132372300359e-11
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   5.9928132372300359e-11    5.9928132372300359e-11
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 4
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 4
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.170
# Total CPU secs in NLP function evaluations           =      0.494
#
# EXIT: Optimal Solution Found.
# Ipopt 3.13.2: nlp_scaling_method=user-scaling
# tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     2658
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     2019
#
# Total number of variables............................:      913
#                      variables with only lower bounds:       52
#                 variables with lower and upper bounds:      812
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      913
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 3.17e+01 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 4.19e-01 1.08e+01  -1.0 3.11e+00    -  9.21e-01 9.78e-01h  1
#    2  0.0000000e+00 4.50e-03 5.09e+00  -1.0 6.45e-02    -  9.91e-01 9.90e-01h  1
#    3  0.0000000e+00 2.94e-08 4.02e-01  -1.7 6.07e-04    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   2.9380616664249104e-08    2.9380616664249104e-08
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   2.9380616664249104e-08    2.9380616664249104e-08
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 4
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 4
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.206
# Total CPU secs in NLP function evaluations           =      0.458
#
# EXIT: Optimal Solution Found.

# %% [markdown]
# ## Show the stream table
#
# The componet fractions that are ``NaN`` (not a number) represent compoenent that are not present in a stream.

# %%
streams_df = m.fs.streams_dataframe()
display(streams_df)
# Out:
#        mass flow (kg/s) mole flow (kmol/s) mole percent Ar (%)  \
# air01       1008.401747          34.946699                0.92
# air02       1008.401747          34.946699                0.92
# air03       1008.401747          34.946699                0.92
# air04a       921.107773           31.92148                0.92
# air04b       921.107773           31.92148                0.92
# air05         63.586306           2.203617                0.92
# air06a        63.586306           2.203617                0.92
# air06b        63.586306           2.203617                0.92
# air07         13.982764            0.48458                0.92
# air08a        13.982764            0.48458                0.92
# air08b        13.982764            0.48458                0.92
# air09          9.724903           0.337022                0.92
# air10a         9.724903           0.337022                0.92
# air10b         9.724903           0.337022                0.92
# fuel01        25.219368           1.462571                 0.0
# g01          946.327141          33.384051            0.879694
# g02a         946.453186          33.426465            0.878578
# g02b         946.453186          33.426465            0.878578
# g03          946.453186          33.426465            0.878578
# g04         1010.039492          35.630083             0.88114
# g05         1010.039492          35.630083             0.88114
# g06         1024.022256          36.114663            0.881661
# g07         1024.022256          36.114663            0.881661
# g08         1033.747159          36.451685            0.882016
#
#        mole percent C2H6 (%) mole percent C3H8 (%) mole percent C4H10 (%)  \
# air01                    NaN                   NaN                    NaN
# air02                    NaN                   NaN                    NaN
# air03                    NaN                   NaN                    NaN
# air04a                   NaN                   NaN                    NaN
# air04b                   0.0                   0.0                    0.0
# air05                    NaN                   NaN                    NaN
# air06a                   NaN                   NaN                    NaN
# air06b                   NaN                   NaN                    NaN
# air07                    NaN                   NaN                    NaN
# air08a                   NaN                   NaN                    NaN
# air08b                   NaN                   NaN                    NaN
# air09                    NaN                   NaN                    NaN
# air10a                   NaN                   NaN                    NaN
# air10b                   NaN                   NaN                    NaN
# fuel01                   3.2                   0.7                    0.4
# g01                 0.140194              0.030667               0.017524
# g02a                     0.0                   0.0                    0.0
# g02b                     NaN                   NaN                    NaN
# g03                      NaN                   NaN                    NaN
# g04                      NaN                   NaN                    NaN
# g05                      NaN                   NaN                    NaN
# g06                      NaN                   NaN                    NaN
# g07                      NaN                   NaN                    NaN
# g08                      NaN                   NaN                    NaN
#
#        mole percent CH4 (%) mole percent CO2 (%) mole percent H2O (%)  \
# air01                   NaN                 0.03                 0.99
# air02                   NaN                 0.03                 0.99
# air03                   NaN                 0.03                 0.99
# air04a                  NaN                 0.03                 0.99
# air04b                  0.0                 0.03                 0.99
# air05                   NaN                 0.03                 0.99
# air06a                  NaN                 0.03                 0.99
# air06b                  NaN                 0.03                 0.99
# air07                   NaN                 0.03                 0.99
# air08a                  NaN                 0.03                 0.99
# air08b                  NaN                 0.03                 0.99
# air09                   NaN                 0.03                 0.99
# air10a                  NaN                 0.03                 0.99
# air10b                  NaN                 0.03                 0.99
# fuel01                 93.1                  1.0                  0.0
# g01                4.078755             0.072496             0.946628
# g02a                    0.0             4.587908             9.722655
# g02b                    NaN             4.587908             9.722655
# g03                     NaN             4.587908             9.722655
# g04                     NaN             4.306014             9.182566
# g05                     NaN             4.306014             9.182566
# g06                     NaN             4.248639             9.072639
# g07                     NaN             4.248639             9.072639
# g08                     NaN             4.209635              8.99791
#
#        mole percent N2 (%) mole percent O2 (%) pressure (bar) temperature (K)  \
# air01                77.32               20.74        1.03421          288.15
# air02                77.32               20.74       0.996438      288.138303
# air03                77.32               20.74      17.437673      674.552025
# air04a               77.32               20.74      17.437673      674.552025
# air04b               77.32               20.74      17.437673      674.552025
# air05                77.32               20.74      17.437673      674.552025
# air06a               77.32               20.74       6.524925      674.535858
# air06b               77.32               20.74       6.524925      674.535858
# air07                77.32               20.74      17.437673      674.552025
# air08a               77.32               20.74       2.580725      674.525898
# air08b               77.32               20.74       2.580725      674.525898
# air09                77.32               20.74      17.437673      674.552025
# air10a               77.32               20.74        1.02594       674.52136
# air10b               77.32               20.74        1.02594       674.52136
# fuel01                 1.6                 0.0        31.0264         310.928
# g01              74.002671           19.831371      17.437673      650.348598
# g02a              73.90877           10.902089       16.56579     1658.192851
# g02b              73.90877           10.902089       16.56579     1658.192851
# g03               73.90877           10.902089       6.524925     1381.612944
# g04              74.119745           11.510535       6.524925     1341.953821
# g05              74.119745           11.510535       2.580725     1111.859291
# g06              74.162685           11.634375       2.580725      1106.44931
# g07              74.162685           11.634375        1.02594      912.061259
# g08              74.191877           11.718563        1.02594             910
#
#        volumetric flow (m**3/s)
# air01                808.943171
# air02                 839.59653
# air03                113.006969
# air04a               103.224333
# air04b               103.224333
# air05                  7.125826
# air06a                18.978913
# air06b                18.978913
# air07                  1.566984
# air08a                10.539035
# air08b                10.539035
# air09                  1.089825
# air10a                18.429033
# air10b                18.429033
# fuel01                 1.142477
# g01                  104.069542
# g02a                  278.95421
# g02b                  278.95421
# g03                   589.25055
# g04                  610.088103
# g05                 1277.092322
# g06                 1288.165536
# g07                 2670.142053
# g08                 2688.970043

# %% [markdown]
# ## Show the PFD
