# %% [markdown]
# # Design flowsheet for the SOEC mode of a reversible Solid Oxide Cell

# %% [markdown]
# ### Process Flow Diagram
# <img src='rsofc_soec_mode_PFD.svg' width=\"300\" height=\"300\">

# %% [markdown]
# ## 1. Introduction
# The figure above shows the process flow diagram of the rSOC plant in SOEC mode. The plant consists of five major sections: the ASU, the SOEC power island, the CPU, the HRSG and steam cycle.
#
# In the SOEC mode, the rSOC operates by using steam as fuel to produce Hydrogen on its fuel side (cathode side), while air is used as sweep gas to remove diffused oxygen from its air side (anode side). To provide air to the air side of the rSOC, ambient air is compressed in an air blower and preheated via two preheaters to reach the required temperature to sweep through the air side. The oxygen rich air stream which exits the air side of the rSOC is used to preheat the fresh air feed in the first air preheater, subsequently it is split in a splitter and used to preheat oxygen from the ASU in the oxygen preheater and natural gas feed in the natural gas preheater. Finally, the oxygen rich air streams from both the oxygen and natural gas preheaters are sent to the HRSG where they are further cooled before release to the atmosphere.
#
# This flowsheet example provides an off-design model for the rSOC in SOEC mode for hydrogen production up to **5 kg/s** with 98% CO2 capture.

# %% [markdown]
# ## 2. Import Required Modules
# - **pyomo environment**. The pyomo environment
# - **rsofc_soec_flowsheet**. Contains functions for the work flow of building and solving the flowsheet. See the rsofc_soec_flowsheet.py file for more details.
# - **rsofc_costing**. Contains costing methods for the soec and sofc operating modes of the reversible sofc. See the rsofc_costing.py file for more details.

# %%
import pyomo.environ as pyo
import rsofc_soec_flowsheet as rsoec
import rsofc_costing as rsofc_cost

# %% [markdown]
# ## 3. Build and initialize the flowsheet
# - A pyomo concrete model is built
# - The **get_model** function in the **rsofc_soec_flowsheet.py** file takes the concrete model as an argument then sets up a flowsheet called **m.soec_fs**, and all the required unit models to it. Finally, the completed flowsheet is initialized. The concrete model and solver options are then returned.

# %%
m = pyo.ConcreteModel()
m, solver = rsoec.get_model(m)
# Out:
# WARNING (W1002): Setting Var
#     'soec_fs.pre_oxycombustor_translator.properties_out[0.0].mole_frac_comp[C2
#     H6]' to a numeric value `0` outside the bounds (1e-20, 1.001).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# WARNING (W1002): Setting Var 'soec_fs.pre_oxycombustor_translator.properties_o
#     ut[0.0].mole_frac_comp[C4H10]' to a numeric value `0` outside the bounds
#     (1e-20, 1.001).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# WARNING (W1002): Setting Var
#     'soec_fs.pre_oxycombustor_translator.properties_out[0.0].mole_frac_comp[CH
#     4]' to a numeric value `0` outside the bounds (1e-20, 1.001).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# WARNING (W1002): Setting Var
#     'soec_fs.pre_oxycombustor_translator.properties_out[0.0].mole_frac_comp[C3
#     H8]' to a numeric value `0` outside the bounds (1e-20, 1.001).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_compressor_s1.control_volume.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_compressor_s1.control_volume.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_compressor_s1.control_volume.work
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_compressor_s1.properties_isentropic[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.intercooler_s1.control_volume.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.intercooler_s1.control_volume.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.intercooler_s1.control_volume.heat
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_compressor_s2.control_volume.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_compressor_s2.control_volume.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_compressor_s2.control_volume.work
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_compressor_s2.properties_isentropic[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.intercooler_s2.control_volume.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.intercooler_s2.control_volume.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.intercooler_s2.control_volume.heat
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.oxygen_preheater.hot_side.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.oxygen_preheater.hot_side.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.oxygen_preheater.hot_side.heat
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.oxygen_preheater.cold_side.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.oxygen_preheater.cold_side.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.oxygen_preheater.cold_side.heat
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.oxygen_preheater.overall_heat_transfer_coefficient[0.0]
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.oxygen_preheater.area
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.ng_preheater.hot_side.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.ng_preheater.hot_side.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.ng_preheater.hot_side.heat
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.ng_preheater.cold_side.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.ng_preheater.cold_side.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.ng_preheater.cold_side.heat
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.ng_preheater.overall_heat_transfer_coefficient[0.0]
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.ng_preheater.area
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_blower.control_volume.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_blower.control_volume.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_blower.control_volume.work
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_blower.properties_isentropic[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_preheater_1.hot_side.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_preheater_1.hot_side.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_preheater_1.hot_side.heat
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_preheater_1.cold_side.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_preheater_1.cold_side.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_preheater_1.cold_side.heat
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_preheater_1.overall_heat_transfer_coefficient[0.0]
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_preheater_1.area
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_preheater_2.hot_side.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_preheater_2.hot_side.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_preheater_2.hot_side.heat
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_preheater_2.cold_side.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_preheater_2.cold_side.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_preheater_2.cold_side.heat
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_preheater_2.overall_heat_transfer_coefficient[0.0]
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_preheater_2.area
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.cmb_mix.ng_state[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.cmb_mix.air_state[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.cmb_mix.mixed_state[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.cmb.control_volume.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.cmb.control_volume.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.cmb.control_volume.heat
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.bhx2.control_volume.heat
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.aux_boiler_feed_pump.control_volume.work
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.bhx1.hot_side.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.bhx1.hot_side.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.bhx1.hot_side.heat
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.bhx1.cold_side.heat
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.bhx1.overall_heat_transfer_coefficient[0.0]
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.bhx1.area
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.mxf1.water_state[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.mxf1.recycle_state[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.mxf1.mixed_state[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.mxa1.air_state[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.mxa1.recycle_state[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.mxa1.mixed_state[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.fuel_recycle_heater.control_volume.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.fuel_recycle_heater.control_volume.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.fuel_recycle_heater.control_volume.heat
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.main_steam_split.h_side_mole_frac_expr[0.0,H2]
# 2022-10-31 15:55:42 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.main_steam_split.h_side_mole_frac_expr[0.0,H2O]
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.oxygen_preheater.overall_heat_transfer_coefficient[0.0]
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.oxygen_preheater.area
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.ng_preheater.overall_heat_transfer_coefficient[0.0]
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.ng_preheater.area
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_preheater_1.overall_heat_transfer_coefficient[0.0]
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_preheater_1.area
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_preheater_2.overall_heat_transfer_coefficient[0.0]
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_preheater_2.area
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.bhx1.overall_heat_transfer_coefficient[0.0]
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.bhx1.area
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp_ic01.control_volume.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp_ic01.control_volume.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp_ic01.control_volume.heat
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp01.control_volume.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp01.control_volume.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp01.control_volume.work
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp01.properties_isentropic[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp_ic02.control_volume.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp_ic02.control_volume.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp_ic02.control_volume.heat
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp02.control_volume.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp02.control_volume.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp02.control_volume.work
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp02.properties_isentropic[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp_ic03.control_volume.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp_ic03.control_volume.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp_ic03.control_volume.heat
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp03.control_volume.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp03.control_volume.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp03.control_volume.work
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp03.properties_isentropic[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp_ic04.control_volume.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp_ic04.control_volume.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp_ic04.control_volume.heat
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp04.control_volume.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp04.control_volume.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp04.control_volume.work
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.hcmp04.properties_isentropic[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.HRSG_2.control_volume.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.HRSG_2.control_volume.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.HRSG_3.control_volume.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.HRSG_3.control_volume.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.HRSG_1.control_volume.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.HRSG_1.control_volume.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.condenser.control_volume.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.condenser.control_volume.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.CPU_translator.properties_out[0.0].mole_frac_comp
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.flash.control_volume.properties_in[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.flash.control_volume.properties_in[0.0].enth_mol_phase[Liq], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.flash.control_volume.properties_in[0.0].mole_frac_comp
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.flash.control_volume.properties_out[0.0].enth_mol_phase[Vap], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.flash.control_volume.properties_out[0.0].enth_mol_phase[Liq], for _enthalpy_flow_term
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.flash.control_volume.properties_out[0.0].mole_frac_comp
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.main_steam_split.h_side_mole_frac_expr[0.0,H2]
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.main_steam_split.h_side_mole_frac_expr[0.0,H2O]
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.bhx1.waterless_flow_expr[0.0]
# 2022-10-31 15:55:43 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.bhx1.waterless_mole_frac_expr[0.0,H2]
# WARNING (W1002): Setting Var
#     'soec_fs.ng_preheater.cold_side.properties_in[0.0].mole_frac_comp[O2]' to
#     a numeric value `0` outside the bounds (1e-20, 1.001).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# WARNING (W1002): Setting Var
#     'soec_fs.ng_preheater.cold_side.properties_in[0.0].mole_frac_comp[Ar]' to
#     a numeric value `0` outside the bounds (1e-20, 1.001).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# WARNING (W1002): Setting Var
#     'soec_fs.ng_preheater.cold_side.properties_in[0.0].mole_frac_comp[H2O]' to
#     a numeric value `0` outside the bounds (1e-20, 1.001).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# WARNING (W1002): Setting Var
#     'soec_fs.ng_preheater.cold_side.properties_in[0.0].mole_frac_comp[O2]' to
#     a numeric value `0` outside the bounds (1e-20, 1.001).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# WARNING (W1002): Setting Var
#     'soec_fs.ng_preheater.cold_side.properties_in[0.0].mole_frac_comp[Ar]' to
#     a numeric value `0` outside the bounds (1e-20, 1.001).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# WARNING (W1002): Setting Var
#     'soec_fs.ng_preheater.cold_side.properties_in[0.0].mole_frac_comp[H2O]' to
#     a numeric value `0` outside the bounds (1e-20, 1.001).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# WARNING (W1002): Setting Var
#     'soec_fs.pre_oxycombustor_translator.properties_out[0.0].mole_frac_comp[C2
#     H6]' to a numeric value `0` outside the bounds (1e-20, 1.001).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# WARNING (W1002): Setting Var 'soec_fs.pre_oxycombustor_translator.properties_o
#     ut[0.0].mole_frac_comp[C4H10]' to a numeric value `0` outside the bounds
#     (1e-20, 1.001).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# WARNING (W1002): Setting Var
#     'soec_fs.pre_oxycombustor_translator.properties_out[0.0].mole_frac_comp[CH
#     4]' to a numeric value `0` outside the bounds (1e-20, 1.001).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# WARNING (W1002): Setting Var
#     'soec_fs.pre_oxycombustor_translator.properties_out[0.0].mole_frac_comp[C3
#     H8]' to a numeric value `0` outside the bounds (1e-20, 1.001).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# WARNING (W1002): Setting Var
#     'soec_fs.pre_oxycombustor_translator.properties_out[0.0].mole_frac_comp[C2
#     H6]' to a numeric value `0` outside the bounds (1e-20, 1.001).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# WARNING (W1002): Setting Var 'soec_fs.pre_oxycombustor_translator.properties_o
#     ut[0.0].mole_frac_comp[C4H10]' to a numeric value `0` outside the bounds
#     (1e-20, 1.001).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# WARNING (W1002): Setting Var
#     'soec_fs.pre_oxycombustor_translator.properties_out[0.0].mole_frac_comp[CH
#     4]' to a numeric value `0` outside the bounds (1e-20, 1.001).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002
# WARNING (W1002): Setting Var
#     'soec_fs.pre_oxycombustor_translator.properties_out[0.0].mole_frac_comp[C3
#     H8]' to a numeric value `0` outside the bounds (1e-20, 1.001).
#     See also https://pyomo.readthedocs.io/en/latest/errors.html#w1002

# %% [markdown]
# ## 4. Base case optimization example
# An example of optimizing the variable operating costs of the model at its base case production of 5 kg/s using the **base_case_optimization** function is shown below. The model also has functions to run a base case simulation (**base_case_simulation**)
# and optimize the variable operating cost of the process over the production range of 1 to 5 kg/s (**optimize_model**)

# %%
rsoec.tags_inputs_opt_vars(m.soec_fs)  # this function adds tags for the optimization variables
rsofc_cost.get_rsofc_soec_variable_OM_costing(m.soec_fs)
rsoec.base_case_optimization(m, solver)
# Out:
# 1000.0*(g/kg)*(0.002*soec_fs.hydrogen_product_rate[0.0]*kg/mol)
# h2_product_rate_mass : Size=1
#     Key : Value
#     0.0 : 10.140202103656495
# 2022-10-31 15:55:44 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.oxygen_preheater.overall_heat_transfer_coefficient[0.0]
# 2022-10-31 15:55:44 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.oxygen_preheater.area
# 2022-10-31 15:55:44 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.ng_preheater.overall_heat_transfer_coefficient[0.0]
# 2022-10-31 15:55:44 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.ng_preheater.area
# 2022-10-31 15:55:44 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_preheater_1.overall_heat_transfer_coefficient[0.0]
# 2022-10-31 15:55:44 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_preheater_1.area
# 2022-10-31 15:55:44 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_preheater_2.overall_heat_transfer_coefficient[0.0]
# 2022-10-31 15:55:44 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.air_preheater_2.area
# 2022-10-31 15:55:44 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.bhx1.overall_heat_transfer_coefficient[0.0]
# 2022-10-31 15:55:44 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.bhx1.area
# 2022-10-31 15:55:44 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.CPU_translator.properties_out[0.0].mole_frac_comp
# 2022-10-31 15:55:44 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.flash.control_volume.properties_in[0.0].mole_frac_comp
# 2022-10-31 15:55:44 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.flash.control_volume.properties_out[0.0].mole_frac_comp
# 2022-10-31 15:55:44 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.main_steam_split.h_side_mole_frac_expr[0.0,H2]
# 2022-10-31 15:55:44 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.main_steam_split.h_side_mole_frac_expr[0.0,H2O]
# 2022-10-31 15:55:44 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.bhx1.waterless_flow_expr[0.0]
# 2022-10-31 15:55:44 [WARNING] idaes.core.util.scaling: Missing scaling factor for soec_fs.bhx1.waterless_mole_frac_expr[0.0,H2]
# Hydrogen product rate 2.500 kmol/s.
# Ipopt 3.13.2: nlp_scaling_method=user-scaling
# tol=0.0001
# bound_push=1e-05
# linear_solver=ma57
# max_iter=500
# ma27_pivtol=0.001
# ma57_pivtol=1e-05
# ma57_pivtolmax=0.1
# option_file_name=C:\Users\BRANDO~1\AppData\Local\Temp\tmpxuzp6xif_ipopt.opt
#
# Using option file "C:\Users\BRANDO~1\AppData\Local\Temp\tmpxuzp6xif_ipopt.opt".
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:    11646
# Number of nonzeros in inequality constraint Jacobian.:       23
# Number of nonzeros in Lagrangian Hessian.............:     6421
#
# Reallocating memory for MA57: lfact (219150)
# Total number of variables............................:     2700
#                      variables with only lower bounds:      484
#                 variables with lower and upper bounds:     1426
#                      variables with only upper bounds:       71
# Total number of equality constraints.................:     2689
# Total number of inequality constraints...............:       11
#         inequality constraints with only lower bounds:        4
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        7
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.1160628e+07 2.57e+03 2.72e+04  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.1160484e+07 2.57e+03 2.72e+04  -1.0 3.13e+05    -  4.15e-05 7.99e-06f  1
#    2  1.1159891e+07 2.57e+03 2.72e+04  -1.0 8.80e+04    -  7.11e-03 4.88e-05f  1
#    3  1.1052126e+07 2.55e+03 2.70e+04  -1.0 1.08e+05    -  7.19e-05 8.83e-03f  1
#    4  1.1037705e+07 2.54e+03 2.69e+04  -1.0 2.69e+04  -4.0 7.45e-03 1.23e-03f  1
#    5  1.1026319e+07 2.54e+03 2.69e+04  -1.0 1.08e+05  -4.5 1.02e-02 9.39e-04f  1
#    6  1.1022927e+07 2.54e+03 2.69e+04  -1.0 3.75e+04  -4.1 3.68e-03 2.90e-04f  1
#    7  1.0593811e+07 3.63e+03 2.60e+04  -1.0 1.55e+05  -4.5 7.33e-04 3.52e-02f  1
#    8  1.0582104e+07 3.63e+03 2.59e+04  -1.0 5.23e+04  -4.1 9.74e-03 1.05e-03f  1
#    9  1.0552649e+07 3.62e+03 2.59e+04  -1.0 1.80e+04    -  1.46e-01 2.76e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  9.0359309e+06 3.02e+03 8.27e+04  -1.0 1.76e+04    -  2.09e-02 1.48e-01f  1
#   11  9.0036666e+06 3.01e+03 8.24e+04  -1.0 1.59e+04    -  6.41e-02 3.87e-03f  1
#   12  7.0718695e+06 2.21e+03 2.12e+05  -1.0 1.53e+04    -  1.54e-01 2.47e-01f  1
#   13  7.0327311e+06 2.19e+03 2.10e+05  -1.0 1.02e+04  -1.9 1.42e-03 7.11e-03f  1
#   14  7.0265203e+06 2.19e+03 2.10e+05  -1.0 4.02e+03  -1.4 5.20e-04 1.14e-03f  1
#   94  2.6469897e+06 4.26e+02 1.81e+03  -2.5 3.32e+01  -1.6 6.14e-01 1.00e+00f  1
#   95  2.6469866e+06 4.26e+02 2.02e+03  -2.5 8.77e+02    -  7.62e-02 4.36e-03f  1
#   96  2.6468246e+06 4.39e+03 1.64e+03  -2.5 1.18e+03    -  1.23e-01 1.68e-01f  1
#   97  2.6468242e+06 4.38e+03 3.89e+03  -2.5 3.04e+02    -  1.00e+00 1.82e-03h  1
#   98  2.6468302e+06 4.53e+02 1.43e+03  -2.5 2.58e+02    -  1.00e+00 1.00e+00h  1
#   99  2.6468308e+06 1.41e+02 4.23e+02  -2.5 8.19e+02    -  9.19e-01 7.03e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100  2.6468311e+06 1.33e+00 5.00e+02  -2.5 1.23e+00  -2.1 1.00e+00 1.00e+00h  1
#  101  2.6468311e+06 1.23e-04 1.41e+03  -2.5 1.47e-01  -2.6 1.00e+00 1.00e+00h  1
#  102  2.6468311e+06 2.56e-06 6.78e+02  -3.8 1.88e-01  -3.0 1.00e+00 1.00e+00f  1
#  103  2.6468311e+06 8.96e+00 8.88e+02  -3.8 1.67e+03    -  7.58e-01 1.00e+00h  1
#  104  2.6468311e+06 3.18e+02 6.05e+02  -3.8 5.97e+04    -  4.58e-01 1.70e-01h  2
#  105  2.6468311e+06 2.04e+01 8.90e+02  -3.8 7.14e+02    -  7.13e-01 1.00e+00h  1
#  106  2.6468311e+06 2.48e+02 3.03e+03  -3.8 3.24e+04    -  3.23e-01 1.68e-01h  2
#  107  2.6468311e+06 3.92e+02 9.92e+03  -3.8 7.90e+03    -  5.63e-01 3.44e-01h  2
#  108  2.6468311e+06 8.17e+01 2.68e+04  -3.8 9.32e+02    -  3.16e-01 1.00e+00H  1
#  109  2.6468311e+06 2.06e+02 6.62e+02  -3.8 1.30e+03    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  110  2.6468311e+06 5.86e+00 1.69e+01  -3.8 5.42e+02    -  1.00e+00 1.00e+00h  1
#  111  2.6468311e+06 1.11e+02 2.43e+03  -3.8 6.80e+02    -  1.00e+00 1.00e+00h  1
#  112  2.6468311e+06 8.16e-01 4.54e+00  -3.8 2.20e+02    -  1.00e+00 1.00e+00h  1
#  113  2.6468311e+06 4.76e-02 1.20e+00  -3.8 1.14e+01    -  1.00e+00 1.00e+00h  1
#  114  2.6468311e+06 3.10e-07 7.29e-06  -3.8 4.99e-02    -  1.00e+00 1.00e+00h  1
#  115  2.6468311e+06 6.31e-04 2.08e-03  -5.0 1.90e+01    -  1.00e+00 1.00e+00f  1
#  116  2.6468311e+06 1.79e-05 1.44e-01  -5.0 2.98e+02    -  1.00e+00 1.00e+00H  1
#
# Number of Iterations....: 116
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.6468311040059179e+06    2.6468311040059179e+06
# Dual infeasibility......:   1.4413991712992916e-01    1.6128777594054747e-02
# Constraint violation....:   1.7940601537702605e-05    1.7940601537702605e-05
# Complementarity.........:   9.0909505203654955e-06    9.0909505203654955e-06
# Overall NLP error.......:   1.7940601537702605e-05    1.6128777594054747e-02
#
#
# Number of objective function evaluations             = 147
# Number of objective gradient evaluations             = 117
# Number of equality constraint evaluations            = 147
# Number of inequality constraint evaluations          = 147
# Number of equality constraint Jacobian evaluations   = 118
# Number of inequality constraint Jacobian evaluations = 118
# Number of Lagrangian Hessian evaluations             = 116
# Total CPU secs in IPOPT (w/o function evaluations)   =     11.054
# Total CPU secs in NLP function evaluations           =      2.201
#
# EXIT: Optimal Solution Found.

# %% [markdown]
# ## 5. Results

# %% [markdown]
# ### a. Input and optimization variables

# %%
rsoec.display_input_tags(m.soec_fs)
# Out:
# soec_outlet_o2_frac
#     O2 side outlet O2 mole fraction
#     display units: None
#     native units: None
#     value 0.350, fixed: True
#
# air_blower_flow
#     Air blower flow (provides air to soec air side)
#     display units: None
#     native units: mol/s
#     value 5697.755 mol/s, fixed: False
#
# combustor_temperature
#     Combustor temperature
#     display units: K
#     native units: K
#     value 2000.000 K, fixed: False
#
# preheat_fg_split_to_oxygen
#     Split frac. of soec air to air preheater, rest goes to NG heater
#     display units: None
#     native units: None
#     value 0.528, fixed: False
#
# soec_h2_split_to_product
#     Split frac. of soec h2 to product, rest goes to recycle
#     display units: None
#     native units: None
#     value 0.500, fixed: False
#
# oxygen_preheater_delta_T_in
#     Air preheater inlet approach temperature
#     display units: K
#     native units: K
#     value 305.893 K, fixed: False
#
# ng_preheater_delta_T_in
#     NG preheater inlet approach temperature
#     display units: K
#     native units: K
#     value 286.823 K, fixed: False
#
# air_preheater_1_delta_T_in
#     air_preheater_1 inlet approach temperature
#     display units: K
#     native units: K
#     value 208.849 K, fixed: False
#
# air_preheater_2_delta_T_in
#     air_preheater_2 inlet approach temperature
#     display units: K
#     native units: K
#     value 976.850 K, fixed: False
#
# soc_cell_potential
#     soc cell potential
#     display units: V
#     native units: V
#     value 1.2510 V, fixed: False
#
# condenser_outlet_temperature
#     Condenser outlet temperature (controls CO2 product purity from CPU)
#     display units: K
#     native units: K
#     value 309.465 K, fixed: False
#
# hydrogen_product_rate
#     Rate of hydrogen production
#     display units: kmol/s
#     native units: mol/s
#     value 2.500 kmol/s, fixed: True
#
# n_cells
#     Number of SOEC cells
#     display units: None
#     native units: None
#     value 3,220,000, fixed: True
#
# feed_water_flow
#     Feed water flow (provides steam to soec fuel side)
#     display units: None
#     native units: mol/s
#     value 3125.313 mol/s, fixed: False
#
# sweep_air_flow
#     Air flow to soec air side
#     display units: None
#     native units: mol/s
#     value 2915.579 mol/s, fixed: False

# %% [markdown]
# ### b. Stream tables

# %%
stream_table = rsoec.stream_tables(m.soec_fs)
stream_table=stream_table.fillna("")  # replace NaN with blank
display(stream_table)
# Out:
#                    flow_mass, kg/s  flow_mol, mol/s  flow_vol, m**3/s  \
# CPU_translator_in        23.722195       877.964729         21.721514
# IC_1_OUT                 84.130257      2915.578823         69.806905
# STAGE_1_OUT              84.130257      2915.578823         64.734941
# STAGE_2_OUT              84.130257      2915.578823         61.523983
# a00                     164.411124      5697.754961        134.722448
# a01                     164.411124      5697.754961        127.764120
# a02                     164.411124      5697.754961        333.977945
# a03                     164.411124      5697.754961        440.640672
# ba00                     84.130257      2915.578823         68.938366
# ba01                     84.130257      2915.578823         59.238132
# ba02                     18.854713       588.938467         11.965931
# ba03                     18.854713       588.938467         11.965931
# bng00                     4.843276       280.880721          7.410316
# bng01                     4.843276       280.880721          7.410316
# bng02                    23.697989       869.819188         22.177978
# cmb_mix_in               18.854713       588.938467         11.965931
# cmb_out                  23.722195       877.964729        140.380865
# fg01                     23.722195       877.964729        140.380865
# fg02                     23.722195       877.964729         67.421355
# fg03                     23.722195       877.964729         28.427125
# fg04                     23.722060       877.964729          0.025731
# h01                      32.598600      6250.000107        465.952428
# h02                      16.299300      3124.999993        232.976210
# h03                       5.039750      2500.000000         56.470505
# h04                       5.039750      2500.000000         56.356957
# h05                       5.039750      2500.000000         28.066486
# h06                       5.039750      2500.000000         20.273843
# h07                       5.039750      2500.000000         10.106486
# h08                       5.039750      2500.000000          7.180621
# h09                       5.039750      2500.000000          3.591657
# h10                       5.039750      2500.000000          2.551483
# hr01                     16.299301      3125.000114        232.976219
# hr02                     16.299301      3125.000114        241.674512
# o01                     204.408652      6947.755961        516.925579
# o02                     204.388212      6947.061185        516.873887
# o03                     204.388212      6947.061185        323.894469
# o04                      96.544958      3281.518671        152.995017
# o05                     107.843253      3665.542514        170.899451
# o06                     107.843253      3665.542514        170.899451
# o07                      96.544958      3281.518671        152.995017
# out01                    65.275544      2326.640356         47.272201
# out02                   107.843253      3665.542514        112.210832
# out03                    96.544958      3281.518671        100.454964
# out08                     5.039750      2500.000000          1.360748
# s00                      56.303380      3125.312524          0.056359
# s01                      56.303380      3125.312524          0.056359
# s02                      56.303380      3125.312524         31.751460
# s03                      56.303380      3125.312524        241.635389
# s04                      56.297750      3124.999993        241.674503
# s05                      72.597050      6250.000107        483.349015
# s06                     164.411152      5697.755961        440.640749
#
#                    temperature, K  pressure, Pa vapor_frac mole_frac_Ar  \
# CPU_translator_in      309.465450  1.040000e+05                0.002056
# IC_1_OUT               310.930000  1.079750e+05                  0.0092
# STAGE_1_OUT            297.543684  1.114220e+05                  0.0092
# STAGE_2_OUT            331.676372  1.306860e+05                  0.0092
# a00                    288.150000  1.013250e+05                  0.0092
# a01                    296.663174  1.100000e+05                  0.0092
# a02                    775.483426  1.100000e+05                  0.0092
# a03                   1023.150010  1.100000e+05                  0.0092
# ba00                   288.150000  1.013250e+05                  0.0092
# ba01                   310.930000  1.272390e+05                  0.0092
# ba02                   310.930000  1.272390e+05                0.003065
# ba03                   310.930001  1.272390e+05                0.003065
# bng00                  330.000000  1.040000e+05                     0.0
# bng01                  330.000001  1.040000e+05                     0.0
# bng02                  318.927617  1.040000e+05                0.002075
# cmb_mix_in             310.930001  1.272390e+05                0.003065
# cmb_out               2000.000020  1.040000e+05                0.002056
# fg01                  2000.000020  1.040000e+05                0.002056
# fg02                   960.549089  1.040000e+05                0.002056
# fg03                   405.000000  1.040000e+05                0.002056
# fg04                   309.465450  1.040000e+05                0.002056
# h01                    986.325031  1.100000e+05
# h02                    986.325031  1.100000e+05
# h03                    298.750613  1.100000e+05
# h04                    298.150000  1.100000e+05
# h05                    419.667048  3.110800e+05
# h06                    303.150000  3.110800e+05
# h07                    426.676604  8.797342e+05
# h08                    303.150000  8.797342e+05
# h09                    426.831805  2.487888e+06
# h10                    303.150000  2.487888e+06
# hr01                   986.325031  1.100000e+05
# hr02                  1023.150010  1.100000e+05
# o01                    984.332824  1.100000e+05                0.007545
# o02                    984.332824  1.100000e+05                0.007545
# o03                    616.823495  1.100000e+05                0.007545
# o04                    616.823495  1.100000e+05                0.007545
# o05                    616.823495  1.100000e+05                0.007545
# o06                    616.823495  1.100000e+05                0.007545
# o07                    616.823495  1.100000e+05                0.007545
# out01                  310.930000  1.272390e+05                0.010753
# out02                  405.000000  1.100000e+05                0.007545
# out03                  405.000000  1.100000e+05                0.007545
# out08                  416.005824  6.479000e+06
# s00                    288.750000  1.013250e+05        0.0
# s01                    288.750613  1.100000e+05        0.0
# s02                    375.445575  1.100000e+05   0.363523
# s03                   1023.150010  1.100000e+05        1.0
# s04                   1023.150010  1.100000e+05
# s05                   1023.150010  1.100000e+05
# s06                   1023.150010  1.100000e+05                  0.0092
#
#                   mole_frac_CO mole_frac_CO2 mole_frac_H2 mole_frac_H2O  \
# CPU_translator_in                   0.333359                   0.641765
# IC_1_OUT                              0.0003                     0.0099
# STAGE_1_OUT                           0.0003                     0.0099
# STAGE_2_OUT                           0.0003                     0.0099
# a00                                   0.0003                     0.0099
# a01                                   0.0003                     0.0099
# a02                                   0.0003                     0.0099
# a03                                   0.0003                     0.0099
# ba00                                  0.0003                     0.0099
# ba01                                  0.0003                     0.0099
# ba02                                     0.0                        0.0
# ba03                                     0.0                        0.0
# bng00                                   0.01                        0.0
# bng01                                   0.01                        0.0
# bng02                               0.003229                        0.0
# cmb_mix_in                               0.0                        0.0
# cmb_out                             0.333359                   0.641765
# fg01                                0.333359                   0.641765
# fg02                                0.333359                   0.641765
# fg03                                0.333359                   0.641765
# fg04                                0.333359                   0.641765
# h01                                                   0.8           0.2
# h02                                                   0.8           0.2
# h03                                                   1.0
# h04                                                   1.0
# h05                                                   1.0
# h06                                                   1.0
# h07                                                   1.0
# h08                                                   1.0
# h09                                                   1.0
# h10                                                   1.0
# hr01                                                  0.8           0.2
# hr02                                                  0.8           0.2
# o01                                 0.000246                   0.008119
# o02                                 0.000246                   0.008119
# o03                                 0.000246                   0.008119
# o04                                 0.000246                   0.008119
# o05                                 0.000246                   0.008119
# o06                                 0.000246                   0.008119
# o07                                 0.000246                   0.008119
# out01                               0.000376                   0.012406
# out02                               0.000246                   0.008119
# out03                               0.000246                   0.008119
# out08                                                 1.0
# s00
# s01
# s02
# s03
# s04                                                   0.0           1.0
# s05                                                   0.4           0.6
# s06                                   0.0003                     0.0099
#
#                   mole_frac_N2 mole_frac_O2 mole_frac_CH4 mole_frac_C2H6  \
# CPU_translator_in     0.006403     0.016417
# IC_1_OUT                0.7732       0.2074
# STAGE_1_OUT             0.7732       0.2074
# STAGE_2_OUT             0.7732       0.2074
# a00                     0.7732       0.2074
# a01                     0.7732       0.2074
# a02                     0.7732       0.2074
# a03                     0.7732       0.2074
# ba00                    0.7732       0.2074
# ba01                    0.7732       0.2074
# ba02                  0.001914     0.995021
# ba03                  0.001914     0.995021           0.0            0.0
# bng00                    0.016          0.0         0.931          0.032
# bng01                    0.016          0.0         0.931          0.032
# bng02                 0.006463      0.67371      0.300637       0.010333
# cmb_mix_in            0.001914     0.995021
# cmb_out               0.006403     0.016417           0.0            0.0
# fg01                  0.006403     0.016417
# fg02                  0.006403     0.016417
# fg03                  0.006403     0.016417
# fg04                  0.006403     0.016417
# h01
# h02
# h03
# h04
# h05
# h06
# h07
# h08
# h09
# h10
# hr01
# hr02
# o01                    0.63409         0.35
# o02                    0.63409         0.35
# o03                    0.63409         0.35
# o04                    0.63409         0.35
# o05                    0.63409         0.35
# o06                    0.63409         0.35
# o07                    0.63409         0.35
# out01                 0.968434     0.008031
# out02                  0.63409         0.35
# out03                  0.63409         0.35
# out08
# s00
# s01
# s02
# s03
# s04
# s05
# s06                     0.7732       0.2074
#
#                   mole_frac_C3H8 mole_frac_C4H10
# CPU_translator_in
# IC_1_OUT
# STAGE_1_OUT
# STAGE_2_OUT
# a00
# a01
# a02
# a03
# ba00
# ba01
# ba02
# ba03                         0.0             0.0
# bng00                      0.007           0.004
# bng01                      0.007           0.004
# bng02                    0.00226        0.001292
# cmb_mix_in
# cmb_out                      0.0             0.0
# fg01
# fg02
# fg03
# fg04
# h01
# h02
# h03
# h04
# h05
# h06
# h07
# h08
# h09
# h10
# hr01
# hr02
# o01
# o02
# o03
# o04
# o05
# o06
# o07
# out01
# out02
# out03
# out08
# s00
# s01
# s02
# s03
# s04
# s05
# s06

# %% [markdown]
# ### c. Print results table

# %%
result_variables = rsoec.initialize_results(m.soec_fs)
results_table = rsoec.results_table_dataframe(result_variables)
print('========================== Overall Results ========================')
print()
print(results_table)
# Out:
# ========================== Overall Results ========================
#
#                             Variable    Value Units
#   soec_fs.hydrogen_product_rate[0.0]  2500.00 mol/s
#     soec_fs.h2_compressor_power[0.0]    35.13    MW
#           soec_fs.soec_power_DC[0.0]   603.51    MW
#           soec_fs.soec_power_AC[0.0]   622.17    MW
#          soec_fs.HRSG_heat_duty[0.0]    64.13    MW
#       soec_fs.ASU_HP_steam_heat[0.0]     3.17    MW
#        soec_fs.steam_cycle_heat[0.0]    60.96    MW
#       soec_fs.steam_cycle_power[0.0]    23.23    MW
#        soec_fs.steam_cycle_loss[0.0]    37.73    MW
#     soec_fs.feedwater_pump_work[0.0]     0.43    MW
#    soec_fs.condensate_pump_work[0.0]     0.01    MW
# soec_fs.steam_turbine_auxiliary[0.0]     0.02    MW
#           soec_fs.misc_BOP_load[0.0]     0.10    MW
#      soec_fs.cooling_water_duty[0.0]    84.47    MW
#  soec_fs.cooling_water_flowrate[0.0]  1235.28  lb/s
#   soec_fs.circulating_pump_work[0.0]     0.18    MW
#      soec_fs.cooling_tower_load[0.0]     0.10    MW
#          soec_fs.auxiliary_load[0.0]    47.19    MW
#      soec_fs.transformer_losses[0.0]     0.21    MW
#               soec_fs.net_power[0.0]   646.35    MW
#          soec_fs.HHV_efficiency[0.0]     5.31  None
#            soec_fs.CO2_captured[0.0] 45443.27 kg/hr
#           soec_fs.CO2_emissions[0.0]  -927.32 kg/hr
#  soec_fs.CO2_capture_efficiency[0.0]     0.98  None
